# %%
import pandas as pd
import numpy as np
import string
import re

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import words

import requests
from tqdm import tqdm
from functools import lru_cache
from concurrent.futures import ThreadPoolExecutor

import matplotlib.pyplot as plt


# Ensure you have the necessary NLTK tokenizer models downloaded
nltk.download('punkt')
nltk.download('words')

# %%
pd.set_option('display.max_columns', None)

# %%
def remove_extra_spaces(text):
    if not (type(text) == str):
        return np.nan
    # Replace multiple spaces with a single space
    cleaned_text = re.sub(r'\s+', ' ', text)
    return cleaned_text.strip()

# %%
df = pd.read_excel('LCReviewsIntegrated_1962-1994.xlsx', engine='openpyxl')

# %%
df['content'] = df['content'].apply(remove_extra_spaces)

# %%
df
# Out:
#        Column1        IdR          IdR_add     Id_Pub1     dateRev  yearRev  \
# 0          0.0     100001         100001_a  p04763894X  1979-11-24     1979
# 1          1.0     100001         100001_b  p790195607  1979-11-24     1979
# 2          2.0     100001         100001_c  p780280946  1979-11-24     1979
# 3          3.0     100001         100001_d  p050474774  1979-11-24     1979
# 4          4.0     100001         100001_e  p161840841  1979-11-24     1979
# ...        ...        ...              ...         ...         ...      ...
# 25935      NaN  100011976  neg_100011976_1  p801624509  1976-02-16     1976
# 25936      NaN  100011976  neg_100011976_2  p802042015  1976-02-16     1976
# 25937      NaN  100011976  neg_100011976_3  p851422616  1976-02-16     1976
# 25938      NaN  100011976  neg_100011976_4  p852024274  1976-02-16     1976
# 25939      NaN  100011976  neg_100011976_5  p802005543  1976-02-16     1976
#
#                                                   title1  \
# 0      Atlantische avond : gedichten / Theun de Vries...
# 1      Huis en tuin : fabels en strips / [door] Leo V...
# 2      Volledig volmaakte oneetbare perzik / [door] G...
# 3      Goede morgen haan / door Gerrit Kouwenaar [tek...
# 4      Het weerlicht op de kimmen : een keuze uit de ...
# ...                                                  ...
# 25935  Berichten voor bezorgde kinderen / door Willem...
# 25936  De verjaardag / Marguerita Rudolph ; [vert. ui...
# 25937  Nee, dat heeft de gorilla gedaan / Shook Hazen...
# 25938  Schoenmaker Anton Tienteen / Kay Chorao ; [ver...
# 25939  Sauwtje Zeevrouw / Monica Maas ; [tekstbewerki...
#
#                                                   title2                name  \
# 0                          Atlantische avond : gedichten      Theun de Vries
# 1                        Huis en tuin : fabels en strips          Leo Vroman
# 2                    Volledig volmaakte oneetbare perzik    Gerrit Kouwenaar
# 3                                      Goede morgen haan    Gerrit Kouwenaar
# 4      Het weerlicht op de kimmen : een keuze uit de ...   Gerrit Achterberg
# ...                                                  ...                 ...
# 25935                   Berichten voor bezorgde kinderen      Willem Wilmink
# 25936                                      De verjaardag  Marguerita Rudolph
# 25937                   Nee, dat heeft de gorilla gedaan      B. Shook Hazen
# 25938                         Schoenmaker Anton Tienteen          Kay Chorao
# 25939                                   Sauwtje Zeevrouw         Monica Maas
#
#             name1        name2     Id_Pers givenName  familyName  \
# 0        Theun de        Vries  p068302770     Theun    de Vries
# 1             Leo       Vroman  p068433026       Leo      Vroman
# 2          Gerrit    Kouwenaar  p068390394    Gerrit   Kouwenaar
# 3          Gerrit    Kouwenaar  p068390394    Gerrit   Kouwenaar
# 4          Gerrit   Achterberg  p068390343    Gerrit  Achterberg
# ...           ...          ...         ...       ...         ...
# 25935      Willem      Wilmink  p06832927X    Willem     Wilmink
# 25936  Marguerita      Rudolph         NaN       NaN         NaN
# 25937          B.  Shook Hazen         NaN       NaN         NaN
# 25938         Kay       Chorao         NaN       NaN         NaN
# 25939      Monica         Maas         NaN       NaN         NaN
#
#                                        fullName  \
# 0                   Vries, Theun de (1907-2005)
# 1                       Vroman, Leo (1915-2014)
# 2                 Kouwenaar, Gerrit (1923-2014)
# 3                 Kouwenaar, Gerrit (1923-2014)
# 4      Achterberg, Gerrit (1905-1962 ; dichter)
# ...                                         ...
# 25935               Wilmink, Willem (1936-2003)
# 25936                                       NaN
# 25937                                       NaN
# 25938                                       NaN
# 25939                                       NaN
#
#                                            alternateName       place  \
# 0                                       P'risi, T'ein de  Buitenpost
# 1                                                    NaN   Amsterdam
# 2                                       Kauvenar, Gerrit   Amsterdam
# 3                                       Kauvenar, Gerrit    Nijmegen
# 4      \u0410\u0445\u0442\u0435\u0440\u0431\u0435\u04...   Amsterdam
# ...                                                  ...         ...
# 25935                                                NaN   Amsterdam
# 25936                                                NaN   Amsterdam
# 25937                                                NaN   Amsterdam
# 25938                                                NaN   Amsterdam
# 25939                                                NaN   Amsterdam
#
#                                                publisher     publisher2  \
# 0      Lykele Jansma in samenw. met de Literaire Krin...  Lykele Jansma
# 1                                                Querido        Querido
# 2                                                Querido        Querido
# 3                                                 Thieme         Thieme
# 4                                                Querido        Querido
# ...                                                  ...            ...
# 25935                                             Kosmos         Kosmos
# 25936                                             Kosmos         Kosmos
# 25937                                             Kosmos         Kosmos
# 25938                                             Kosmos         Kosmos
# 25939                                             Kosmos         Kosmos
#
#       publisherId translationOfWork genre        ISBN bookFormat birthDate  \
# 0      _:b7849391               NaN  Book  9062721915  PrintBook      1907
# 1      _:b9649699               NaN  Book  9021486806  PrintBook      1915
# 2      _:b9276628               NaN  Book  9021471418  PrintBook      1923
# 3      _:b7971295               NaN  Book         NaN  PrintBook      1923
# 4      _:b8602066               NaN  Book  9021450291  PrintBook      1905
# ...           ...               ...   ...         ...        ...       ...
# 25935         NaN               NaN   NaN         NaN        NaN       NaN
# 25936         NaN               NaN   NaN         NaN        NaN       NaN
# 25937         NaN               NaN   NaN         NaN        NaN       NaN
# 25938         NaN               NaN   NaN         NaN        NaN       NaN
# 25939         NaN               NaN   NaN         NaN        NaN       NaN
#
#       deathDate subject2 subject3 publicationId yearPub bookEdition  \
# 0          2005      NaN      NaN   _:b12370168    1979         NaN
# 1          2014      NaN      NaN   _:b14170476    1979         NaN
# 2          2014      NaN      NaN   _:b13797405    1978         NaN
# 3          2014      NaN      NaN   _:b12492072    1978         NaN
# 4          1962      NaN      NaN   _:b13122843    1979       2e dr
# ...         ...      ...      ...           ...     ...         ...
# 25935       NaN      NaN      NaN           NaN     NaN         NaN
# 25936       NaN      NaN      NaN           NaN     NaN         NaN
# 25937       NaN      NaN      NaN           NaN     NaN         NaN
# 25938       NaN      NaN      NaN           NaN     NaN         NaN
# 25939       NaN      NaN      NaN           NaN     NaN         NaN
#
#             numberOfPages                                            comment  \
# 0                 [20] bl                                          Med. NLMD
# 1      40 p., [12] bl. pl                                          Med. NLMD
# 2                    64 p                                          Med. NLMD
# 3                  [16] p                                          Med. NLMD
# 4                   167 p                                          Med. NLMD
# ...                   ...                                                ...
# 25935                48 p                                                NaN
# 25936                30 p                                                NaN
# 25937                31 p                                                NaN
# 25938                45 p  The repair of uncle Toe. - New York : Farrar S...
# 25939                29 p                                                NaN
#
#                                              description inLanguage isPartOf  \
# 0                                                    NaN        ned      NaN
# 1                                                    NaN        ned      NaN
# 2                                                    NaN        ned      NaN
# 3      Facs. herdr. van uitg.: Amsterdam : Experiment...        ned      NaN
# 4                                         1e uitg.: 1965        ned      QED
# ...                                                  ...        ...      ...
# 25935                                                NaN        ned      NaN
# 25936                                                NaN        ned      NaN
# 25937                                                NaN        ned      NaN
# 25938                                                NaN        ned      NaN
# 25939                                                NaN        ned      NaN
#
#       subject1 genreNews PiCartaDNB Manual  \
# 0          NaN   artikel        NaN    NaN
# 1          NaN   artikel        NaN    NaN
# 2          NaN   artikel        NaN    NaN
# 3          NaN   artikel        NaN    NaN
# 4          NaN   artikel        NaN    NaN
# ...        ...       ...        ...    ...
# 25935      NaN   artikel        NaN    NaN
# 25936      NaN   artikel        NaN    NaN
# 25937      NaN   artikel        NaN    NaN
# 25938      NaN   artikel        NaN    NaN
# 25939      NaN   artikel        NaN    NaN
#
#                                                  content
# 0      Camperts Theater Overigens is de titel van dez...
# 1      Camperts Theater Overigens is de titel van dez...
# 2      Camperts Theater Overigens is de titel van dez...
# 3      Camperts Theater Overigens is de titel van dez...
# 4      Camperts Theater Overigens is de titel van dez...
# ...                                                  ...
# 25935  boeken Handzame, maar geen vrijblijvende kinde...
# 25936  boeken Handzame, maar geen vrijblijvende kinde...
# 25937  boeken Handzame, maar geen vrijblijvende kinde...
# 25938  boeken Handzame, maar geen vrijblijvende kinde...
# 25939  boeken Handzame, maar geen vrijblijvende kinde...
#
# [25940 rows x 41 columns]

# %%
# Load the OpenTaal word list
with open('word_dictionary/OpenTaal-210G-basis-gekeurd.txt', 'r') as file:
    dutch_words = set(word.strip().lower() for word in file.readlines())

# %%
len(dutch_words)
# Out:
# 164105

# %%
# Load the OpenTaal word list with the correct encoding
with open('word_dictionary/openthesaurus.txt', 'r', encoding='utf-8') as file:
    german_words = set(word.strip().lower() for word in file.readlines())

german_dict1 = set()

# Iterate through each string in the multi-word set
for multi_word in german_words:
    # Remove parentheses and their contents
    multi_word = re.sub(r'\(.*?\)', '', multi_word)
    # Split the string by semicolons and spaces, and add each word to the set
    words = re.split(r'[; ]+', multi_word)
    german_dict1.update(word.strip() for word in words if word.strip())

# %%
with open('word_dictionary/de_DE.dic', 'r') as file:
    german_words = set(word.strip().lower() for word in file.readlines())

# Remove the trailing '/...' part from each word
german_words = set(word.split('/')[0] for word in german_words)

# %%
german_words.update(german_dict1)

# %%
len(german_words)
# Out:
# 164913

# %%
def check_word_in_both_dictionaries(word):
    word = word.lower()
    if word in dutch_words:
        return True
    elif word in german_words:
        return True
    else: 
        return False

# Define a function to calculate the percentage of words that exist in both dictionaries for each sentence
def calculate_both_dictionaries_percentage(sentence):
    words = sentence.split()
    total_words = len(words)
    both_count = sum(1 for word in words if check_word_in_both_dictionaries(word))
    both_percentage = (both_count / total_words) * 100
    return both_percentage

# %%
unique_df = df[['yearRev', 'content']].drop_duplicates()
unique_df
# Out:
#        yearRev                                            content
# 0         1979  Camperts Theater Overigens is de titel van dez...
# 8         1972  INGEBOEKT * PANDA en KAPPIE. De avonturen van ...
# 15        1985  Boeken Familiekroniek, à la García Marquez deb...
# 16        1981  boeken Deltas fotoboek goed basiswerk HARRY PA...
# 17        1981  Ingeboekt * RAYMOND RADIGUET - „Het bal van gr...
# ...        ...                                                ...
# 25925     1966  Boeken voor: Kleuters en kwajongens Voor de kl...
# 25929     1979  Proza van Eric Terduyn, Aleida Leeuwenberg en ...
# 25932     1989  Dood van een komiek J. BERNLEF - Vallende ster...
# 25933     1988  Vederlichte verhaaltjes Kees van Kooten zoekt ...
# 25935     1976  boeken Handzame, maar geen vrijblijvende kinde...
#
# [13129 rows x 2 columns]

# %%
unique_df['correct_ocr_percentage'] = unique_df['content'].apply(calculate_both_dictionaries_percentage)

# %%
# Group by 'yearRev' and calculate the mean of 'correct_ocr_percentage'
aggregated_data = unique_df.groupby('yearRev')['correct_ocr_percentage'].mean().reset_index()

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(aggregated_data['yearRev'], aggregated_data['correct_ocr_percentage'], marker='o')
plt.title('Percentage of Tokens Present in Dutch or German Dictionary Over Time')
plt.xlabel('Year')
plt.ylabel('Tokens Present in Dutch or German Dictionary (%)')
plt.grid(True)
plt.show()

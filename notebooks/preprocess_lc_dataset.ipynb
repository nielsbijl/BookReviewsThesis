# %% [markdown]
# # Locating the Provided NBT Book Titles in Newspaper Reviews
#
# In this notebook, we aim to determine the location of given book titles from the Nederlandse Bibliografie Totaal (NBT) database within newspaper book review articles. The process involves multiple steps to ensure accurate matching:
#
# 1. **Direct Matching:** Initially, we attempt to directly match the given NBT titles with the text in the newspaper book reviews.
# 2. **Main Title Extraction:** If a direct match is not found, we truncate the NBT title to retain only the main title.
# 3. **Fuzzy Matching:** If the main title still does not appear directly in the text, we apply fuzzy matching on the main title to locate it within the review.
#
# By the end of this notebook, we will have a transformed dataset which makes the provided dataset a NER dataset.
#
# Let's get started!

# %%
import pandas as pd
import numpy as np
import string
import re

import nltk
from nltk.tokenize import word_tokenize

import os
from datetime import datetime
import json
import difflib
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

from tqdm import tqdm

# Ensure you have the necessary NLTK tokenizer models downloaded
# nltk.download('punkt')

# %%
pd.set_option('display.max_columns', None)

# %%
def remove_extra_spaces(text):
    if not (type(text) == str):
        return np.nan
    # Replace multiple spaces with a single space
    cleaned_text = re.sub(r'\s+', ' ', text)
    return cleaned_text.strip()

# %%
df = pd.read_excel('to_clean3.xlsx', engine='openpyxl')

# %%
# Mannually cleaned till 11286
df.loc[11286 + 1:, 'title3'] = np.nan

# %%
df['content'] = df['content'].apply(remove_extra_spaces)
df['title1'] = df['title1'].apply(remove_extra_spaces)
df['title2'] = df['title2'].apply(remove_extra_spaces)
df['title3'] = df['title3'].apply(remove_extra_spaces)

# %%
def find_best_match(large_text, query_sentence):
    # Initialize the SequenceMatcher
    s = difflib.SequenceMatcher(None, large_text, query_sentence)
    
    # Find the best match in the large text
    match = s.find_longest_match(0, len(large_text), 0, len(query_sentence))
    
    # Calculate similarity ratio
    match_similarity = s.ratio()  # This considers the overall similarity, not just the best match
    
    # Adjust the start position to the beginning of a word
    start = match.a
    while start > 0 and large_text[start - 1] != ' ':
        start -= 1

    # Re-calculate the end position based on the new start position
    end = start + len(query_sentence)

    # Extract the best matching text from the new start to the original match length
    best_match_text = large_text[start:end]

    return start, end, best_match_text, match_similarity

def fuzzy_extract_matching_substring(query, text):
    # Split the query and text into tokens
    query_tokens = query.split()
    text_tokens = text.split()
    
    # Length of the query in terms of tokens
    query_length = len(query_tokens)
    
    # Initialize best match variables
    best_match = ""
    highest_score = 0
    
    # Loop through the text tokens to form segments with the same number of tokens as the query
    for i in range(len(text_tokens) - query_length + 1):
        # Create a segment from the text with the same number of tokens as the query
        segment = " ".join(text_tokens[i:i + query_length])
        
        # Calculate fuzzy match score between the query and the segment
        score = fuzz.token_set_ratio(query, segment)
        if score > highest_score:
            highest_score = score
            best_match = segment

    return best_match, highest_score

# %% [markdown]
# ### Extract main title from title1 (that is present in the review)

# %%
yes = 0
almost_match = 0

titles = []

partially_matched = [0] * len(df)
partially_matched_original_title = ["NONE"] * len(df)

for index, row in tqdm(df.iterrows()):
    if (type(row['title3']) == str): # if not nan
        title = row['title3'].lower()
        if (title in row['content'].lower()):
            yes += 1
            titles.append(title)
            continue

    title = row.title1.split("/")[0]
    title = re.sub(r'#.*?#', '', title) # Remove #..#
    title = title.replace("...", "")
    
    if (title.lower() in row.content.lower()):
        yes += 1
        titles.append(title)
    elif (title.split(":")[0].lower().strip() in row.content.lower()):
        yes += 1
        titles.append(title.split(":")[0].strip())
    elif (title.split(":")[0].split(';')[0].lower().strip() in row.content.lower()):
        yes += 1
        titles.append(title.split(":")[0].split(';')[0].strip())
    elif (title.split(":")[0].split(';')[0].split('=')[0].lower().strip() in row.content.lower()):
        yes += 1
        titles.append(title.split(":")[0].split(';')[0].split('=')[0].strip())
    elif (title.split(":")[0].split(';')[0].split(',')[0].lower().strip() in row.content.lower()):
        yes += 1
        titles.append(title.split(":")[0].split(';')[0].split(',')[0].strip())
    else:
        best_match_text, match_similarity = fuzzy_extract_matching_substring(text=row.content.lower(), query=title.split("/")[0].split(":")[0].split(';')[0].lower())
        if (match_similarity > 0.1):
            yes += 1
            almost_match += 1
            partially_matched[index] = 1
            partially_matched_original_title[index] = title.split("/")[0].split(":")[0].split(';')[0].lower()
            
            titles.append(best_match_text)
        else:
            titles.append(np.nan)
# Out:
# 25940it [01:24, 306.29it/s]

# %%
yes / len(df)
# 0.7492675404780262
# Out:
# 1.0

# %%
almost_match
# Out:
# 6562

# %%
df['partially_matched'] = partially_matched
df['title4'] = titles
df['partially_matched_original_title'] = partially_matched_original_title
df['manually_removed'] = [0] * len(df)

# %%
f"The number of titles we found: {len(df['title4']) - df['title4'].isnull().sum()}"
# Out:
# 'The number of titles we found: 25940'

# %%
f"The number of unique reviews where we found the title: {len(df[df['title4'].notnull()].content.unique())}"
# Out:
# 'The number of unique reviews where we found the title: 13129'

# %% [markdown]
# ### Export cleaned df

# %%
# Keep only the records where the title was found in the review
df_clean = df[df['title4'].notnull()]

# %%
# Export df to excel
df_clean.to_excel('xxxxxxx.xlsx', index=False, engine='openpyxl')

# %%
# Dubble check if all the titles are actually in the review
for index, row in df_clean.iterrows():
    if not (row['title4'].lower() in row['content'].lower()):
        print(row['title4'])

# %% [markdown]
# ### Check partially matching quality

# %%
count = 0

for index, row in df[df['title4'].isnull()].iterrows():

    title = row.title1.split("/")[0]
    title = re.sub(r'#.*?#', '', title) # Remove #..#
    title = title.replace("...", "")
    
    start, end, best_match_text, match_similarity = find_best_match(large_text=row.content.lower(), query_sentence=title.split("/")[0].split(":")[0].split(';')[0].lower())
    if (match_similarity > 0.005):
        count += 1
        
        print(best_match_text)
        print(title.split("/")[0].split(":")[0].split(';')[0].lower())
        print("\n\n")

# %%
count

# %%
count = 0

for index, row in df[df['title4'].isnull()].iterrows():

    title = row.title1.split("/")[0]
    title = re.sub(r'#.*?#', '', title) # Remove #..#
    title = title.replace("...", "")
    
    best_match_text, match_similarity = fuzzy_extract_matching_substring(text=row.content.lower(), query=title.split("/")[0].split(":")[0].split(';')[0].lower())
    if (match_similarity > 80):
        count += 1
        
        print(best_match_text)
        print(title.split("/")[0].split(":")[0].split(';')[0].lower())
        print("\n\n")
# Out:
# het weerhcht op de kimmen;
# het weerlicht op de kimmen
#
#
#
# de modemeester en het
# panda en de modemeester
#
#
#
# modemeester en het geheimzinnige glas water;
# panda en het geheimzinnige glas water
#
#
#
# bij het geheim van de oude prentbriefkaarten en
# kappie en het geheim van de oude prentbriefkaarten
#
#
#
# en bij de slaapslaven.
# kappie en de slaapslaven
#
#
#
# en om de manege. de
# in en om de manege
#
#
#
# mortho-anna jarings.
# martha-anna jarings
#
#
#
# - „de ogen van de
# de ogen van de mol
#
#
#
# „fantasie für got
# fantasie fur gott
#
#
#
# laßrava,
# labrava
#
#
#
# „zitten, zat gezeten".
# zitten zat gezeten
#
#
#
# - zeven eeuwen mijnen en mijnwerkers in
# zeven eeuwen mijnen en mijnwerkers in limburg
#
#
#
# help, ik heb een camera gekregen
# help! ik heb een camera gekregen
#
#
#
# midden van koningen rust hij in vrede.
# temidden van koningen rust hij in vrede
#
#
#
# de ring van moebius 2,
# de ring van möbius 2
#
#
#
# 'hoe bevalt de keizersnede?'
# hoe bevalt een keizersnede?
#
#
#
# met wome wimpers. de
# rose, met vrome wimpers
#
#
#
# place dient op de lijst van soft drugs te worden geplaatst" —
# 'peyton place dient op de lijst van soft drugs te worden geplaatst'
#
#
#
# — geestesdoop en
# geestesdoop en tongentaal
#
#
#
# ders: „vogelveldgids van europa".
# kosmos vogelveldgids van europa
#
#
#
# — „een zekere
# een zekere gelijkenis
#
#
#
# — de
# de deelneming
#
#
#
# holleman: handboek voor de combi-magnetron.
# handboek voor de combi magnetron
#
#
#
# de boeken van de omstuimige zuidenwind.
# de boeken van de onstuimige zuidenwind
#
#
#
# — die theorie demokratischer
# die theorie demokratischer elitenherrschaft
#
#
#
# -*• informatie in woord en beeld. weer zijn
# informatie in woord en beeld over het weer
#
#
#
# chandu: „de wonderbaarlijke wereld der toekomstvoorspellers",
# de wonderbaarlijke wereld van de toekomstvoorspellers
#
#
#
# 25 jaar parijs m 25 verhalen.
# 25 jaar parijs in 25 verhalen
#
#
#
# hoe
# hoe-korter-hoe-liever
#
#
#
# .jlaar een multinationale vakbeweging?"
# naar een multinationale vakbeweging?
#
#
#
# a mendels"
# josepha mendels
#
#
#
# „hcrmun krebbers
# herman krebbers
#
#
#
# „een stad oan het water".
# een stad aan het water
#
#
#
# - „mooi dik is 'elijk".
# mooi dik is niet lelijk
#
#
#
# zorg en de haat.
# zorg en de staat
#
#
#
# luistert nauw. dei
# het luistert nauw
#
#
#
# *net ontmoering in eldorado
# de ontmoeting in eldorado
#
#
#
# regenvolgels
# regenvogels
#
#
#
# de wereld van de islam in onze tüd.
# de wereld van de islam in onze tijd
#
#
#
# 'het landgoed bohin'
# het landgoed bohiń
#
#
#
# het" gerecht met de engel
# het gevecht met de engel
#
#
#
# moois voor god -
# iets moois voor god
#
#
#
# verdwenen heden
# verdwenen goden
#
#
#
# audiëntie bij de paus -
# op audiëntie bij de paus
#
#
#
# rudi boltesd» (beter blote jan dode jan en andere "ltsp,eng_ran louis paul boon.
# beter blote jan dan dode jan, en andere uitspraken van louis paul boon
#
#
#
# c. i_. ï>. crone.
# c. c. s. crone
#
#
#
# ,j)e nederlandse visserij rond 1900",
# de nederlandse visserij rond 1900
#
#
#
# llt zoek een domme man.
# ik zoek een domme man
#
#
#
# -eputatiebehartlglng.
# reputatiebehartiging
#
#
#
# ★ de
# de tovertam
#
#
#
# - „rechter
# rechter ooka-mysteries
#
#
#
# - ..een brief voor
# een brief voor anchiry
#
#
#
# „idte griechische phüosophie"
# die griechische philosophie
#
#
#
# ,_agyptische kunst"
# ägyptische kunst
#
#
#
# ,_agyptische kunst"
# ägyptische kunst
#
#
#
# „lorbeer und polme"
# lorbeer und palme
#
#
#
# grebbeltnie 1940.
# grebbelinie 1940
#
#
#
# knotsgekke uitvindingen van de 19de eeuw.
# knotsgekke uitvindingen van de 19e eeuw
#
#
#
# mijn aangenomen zoon
# zijn aangenomen zoon
#
#
#
# mogelijk. dat noord-sumatra in oorlogstijd. oorspronkelijke dagboeken uit interneringskampen chronologisch samengevoegd. aek paminke 1,11 maart - 31 december 1942.
# noord sumatra in oorlogstijd. oorspronkelijke dagboeken uit interneringskampen chronologisch samengevoegd. aek paminke i. 11 maart - 31 december 1942
#
#
#
# koerier, tussen gisteren en morgen.
# koerier tussen gisteren en morgen
#
#
#
# „kies je vijanden net zorg".
# kies je vijanden met zorg
#
#
#
# christenen in china
# christenen en china
#
#
#
# - „de
# de onsterfelijken
#
#
#
# * liz sanderson
# liz sanderson's kruidenremedies
#
#
#
# ln het schuim van grauwe wolken.
# in het schuim van grauwe wolken
#
#
#
# „denken met hn hart"
# denken met het hart
#
#
#
# „kamerplanten in geuren en weuren".
# kamerplanten in geuren en kleuren
#
#
#
# het raadsel, of
# het raadsel mars
#
#
#
# „waarom koop .k die fotocamera"
# waarom koop ik die filcamera?
#
#
#
# „waarom koop .k die fotocamera"
# waarom koop ik die fotocamera?
#
#
#
# la brun, de merrie.
# la bruja, de merrie
#
#
#
# . het
# het landleven
#
#
#
# ,jtent u ze nog? de wargaasters.
# kent u ze nog de wargaasters
#
#
#
# „licht onder de zon".
# licht onder de horizon
#
#
#
# — vrije tyd, blije
# vrije tijd, blije tijd
#
#
#
# goeie ouwe snow.
# goeie ouwe snoopy
#
#
#
# — de legende van tijl uilenspiegel en lamme
# de legende van tijl uilenspiegel en lamme goedzak
#
#
#
# veel water zo dicht bij huis.
# zoveel water zo dicht bij huis
#
#
#
# 'o zoet mysterie van ne ven'
# o zoet mysterie van het leven
#
#
#
# oe transcendente meditatietechniek en de
# transcendente meditatietechniek in de psychiatrie
#
#
#
# „ernst en omvang run ongevallen in de privésfeer".
# ernst en omvang van ongevallen in de privésfeer
#
#
#
# ..magie en mysterie mei mathematiek.
# magie en mysterie met mathematiek
#
#
#
# reizen" —
# gullivers reizen
#
#
#
# vandenberg, de vloek "f.w farao's
# de vloek van de farao's
#
#
#
# maigret en bet huls van de rechter.
# maigret en het huis van de rechter
#
#
#
# het pistool van maifrct.
# het pistool van maigret
#
#
#
# „zonetherapie door voetmassage",
# zone-therapie door voetmassage
#
#
#
# „elsevier duivengids".
# elseviers duivengids
#
#
#
# leopotd 71 van saksen coburgs allergrootste zaak.
# leopold ii van saksen coburgs allergrootste zaak
#
#
#
# „een boekje open over.." -
# een boekje open over joghurt
#
#
#
# de „een boekje open over.." -
# een boekje open over pure sappen
#
#
#
# „kleine pensen m een grote wereld".
# kleine mensen in de grote wereld
#
#
#
# „huismiddelties uit grootmoeders apotheek".
# huismiddeltjes uit grootmoeders apotheek
#
#
#
# „adders onder adders".
# adder onder adders
#
#
#
# zo leefde het rome der pausen in de 18de eeuw.
# zo leefde het rome der pausen in de 18e eeuw
#
#
#
# „een non in de fcost",
# een non in de kast
#
#
#
# „het avontuur van de grote mcaulnes",
# het avontuur van de grote meaulnes
#
#
#
# „de trip van john en yoko".
# de trip van john & yoko
#
#
#
# „ais je rioo/d is geboord".
# als je hoofd is geboord
#
#
#
# de wonderen «on de heiland,
# de wonderen van de heiland
#
#
#
# la senora
# la señora
#
#
#
# pilnjak: stad der stormen. verhalen en
# stad der stormen en andere verhalen
#
#
#
# 'de gouden beker'
# een gouden beker
#
#
#
# — nöchtlicher
# nächtlicher weg
#
#
#
# carmiggelt tony van verre: ,tony van
# tony van verre ontmoet simon carmiggelt
#
#
#
# .weerzien bij pas-
# weerzien bij passendale
#
#
#
# wem gehort der ozean?
# wem gehört der ozean?
#
#
#
# is christelijk
# christelijk bewustzijn
#
#
#
# de n. c. r. v.".
# \ hier hilversum, de n.c.r.v.\
#
#
#
# 'van hofballet tot postmoderne
# van hofballet tot postmoderne-dans
#
#
#
# van de rebellenclub. op de golf
# sjors van de rebellenclub en sjimmie
#
#
#
# laan: „de ogem-dossiers",
# de ogem dossiers
#
#
#
# 'ook dat nog':
#  ook dat nog!
#
#
#
# in indié geweest.
# in indië geweest
#
#
#
# -„ttoeede dagboek van een herdershond".
# tweede dagboek van een herdershond
#
#
#
# (aarts' letterkundige a\^n'. nak voor het schrikkeljaar
# aarts' letterkundige almanak voor het schrikkeljaar 1980
#
#
#
# nederlands-indië 1940-1946.
# nederlands-indie 1940-1946
#
#
#
# - „het geslacht uit
# het geslacht der gedachten
#
#
#
# langenhoff: weer en natuur, van dag tot
# weer en natuur van dag tot dag
#
#
#
# de wereld van gabriel garcia marquez,
# de wereld van gabriel garcía márquez
#
#
#
# geschiedenis van het weeshuis der gerefor/meerden binnen delft. in opdracht
# geschiedenis van het weeshuis der gereformeerden binnen delft, te delft
#
#
#
# 6' ™
# continent 6
#
#
#
# „het guat uitstekend,
# het gaat uitstekend
#
#
#
# van mijn oorsprong), c.
# land van mijn oorsprong
#
#
#
# (eens rrtin«<"•* doop heeft aadlaars wieken:
# eens minnaars hoop heeft adelaars wieken
#
#
#
# moord tn de eerste graad.
# moord in de eerste graad
#
#
#
# - „in
# in drievoud
#
#
#
# - „het verloren
# het verloren woud
#
#
#
# de nederlandse reageerbuisbaby
# reageerbuisbaby's in nederland
#
#
#
# leven - ander recht"
# nieuw leven, ander recht
#
#
#
# met 'verdronken land'
# het verdronken land
#
#
#
# boeken de "rsv-show":
# de rsv show
#
#
#
# - „vleesboek
#  prisma vleesboek
#
#
#
# t. k. basu - „goede voeding voor moeder en kind",
# een boekje open over goede voeding voor moeder en kind
#
#
#
# - „vleesboek
#  prisma vleesboek
#
#
#
# - ..de
# de overkant
#
#
#
# — „bijbelse
# bijbelse dagkalender
#
#
#
# aangedurfd. spectrum-wijnatlas
# spectrum wijnatlas
#
#
#
# het goud van tomas vargas.
# het goud van tomás vargas
#
#
#
# de vrouw met de blauwe ogen. verhalen, uit het
# de vrouw met de blauwe ogen en andere verhalen
#
#
#
# — kleuters onderweg gevaarlijker dan u
# kleuters onderweg gevaarlijker dan u denkt!
#
#
#
# lezingen over de verhouding marxismesociologie. in
# 8 lezingen over de verhouding sociologie-marxisme
#
#
#
# ..hop komen wii aan onze nam.en".
# hoe komen wij aan onze namen
#
#
#
# johannes, boer to wergea, en syn nei team",
# johannes johannes boer to wergea en syn neiteam
#
#
#
# askerland, inventaris der archieven" van
# inventaris der archieven van haskerland
#
#
#
# in oude ansichten h.
#  wassenaar in oude ansichten
#
#
#
# t het leven.
# uit het leven
#
#
#
# toussie salomonson -„wild en gevogelte boek".
# het groot wild en gevogelte boek
#
#
#
# ue armada.
# de armada
#
#
#
# wandelingen door home.
# wandelingen door rome
#
#
#
# „de wisselhandet'.
# de wisselhandel
#
#
#
# ..mens
# mens-zijn
#
#
#
# „hééé iöh! kom je buiten spelen".
# hééé jôh! kom je buiten spelen
#
#
#
# de landschapsjotograaj (en andere verhalen)
# de landschapsfotograaf en andere verhalen
#
#
#
# - [* stormwind van zijn
# de stormwind van zijn hand
#
#
#
# - ** icijn is drinkbaar dank zij net
# de wijn is drinkbaar dank zij het glas
#
#
#
# omtrent „komen en gaan" van maurice roelants;
# omtrent 'komen en gaan' van maurice roelants
#
#
#
# incarnatie;
# incantatie
#
#
#
# o k.
# blijf o.k.
#
#
#
# „smakelijk schikleert",
# smakelijk schikken
#
#
#
# van een eenzame wandelaar. uil
# overpeinzingen van een eenzame wandelaar
#
#
#
# „middeleeuwse stadswallen en stads-poorten in de lage landen.
# middeleeuwse stadswallen en stadspoorten in de lage landen
#
#
#
# een komeet boven moemuauet
# een komeet boven moemvallei
#
#
#
# - „dubbelspel in- damascus".
# dubbel spel in damascus
#
#
#
# elke vrouw in de middenjaren
# de vrouw in de middenjaren
#
#
#
# de //,,
# de meermin
#
#
#
# het huis in de //,,
# het huis in de gortstraat
#
#
#
# rlock holmes omnibus.
# sherlock holmes omnibus
#
#
#
# „katastrofe in kükduin"
# katastrofe in kijkduin
#
#
#
# chagall „chagall bv
# chagall by chagall
#
#
#
# wie is budding"
# wie is budwing?
#
#
#
# „vaarwel scheveningen". bonte
# vaar wel, scheveningen!
#
#
#
# ,flet grote kruissteekboek".
# het grote kruissteekboek
#
#
#
# grote kerstboek -
# het grote kerstboek
#
#
#
# - „drentse willekeuren", uit oudere uitgaven
# drentse willekeuren uit oudere uitgaven verzameld
#
#
#
# „een hart onder liei liarnas".
# een hart onder het harnas
#
#
#
# - „ziekten bij
# ziekten bij volièrevogels
#
#
#
# - „menuboek"
# nrc-handelsblad menuboek
#
#
#
# oranje nassau en friesland.
# oranje nassau & friesland
#
#
#
# - „200 smaaktips" (voor
# 200 smaaktips voor kant-en-klaargerechten
#
#
#
# bowlers aan feyenoörd.
# bouwers aan feyenoord
#
#
#
# kaas a la carte.
# kaas à la carte
#
#
#
# genderstrom
# genderstrøm
#
#
#
# ..zwervend door hel franse leven".
# zwervend door het franse leven
#
#
#
# „hersensaboiuge".
# hersensabotage
#
#
#
# ..klseviers almanak voor het erfrecht".
# elseviers almanak voor het erfrecht
#
#
#
# ('73-74', an anual of new art and artists,
# an annual of new art and artists '73-'74
#
#
#
# - „lekkere
# lekkere gehakt-gerechten
#
#
#
# de bloei ran het leven.
# de bloei van het leven
#
#
#
# - „lekkere barbecueen grillgerechten"
# lekkere barbecue- en grillrechten
#
#
#
# lapide: is dat niet •n van jozef?.
# is dat niet de zoon van jozef?
#
#
#
# „met mijn moordenaar tijd ben ie alleen".
# met mijn moordenaar tijd ben ik alleen
#
#
#
# „het groot guiness record boek
# het groot guinness record boek
#
#
#
# het kleine jeaskroetboek
# het kleine kaskroetboek
#
#
#
# dekkers: „de kikvorsen andere beesten".
# de kikvors en andere beesten
#
#
#
# ★ „knippen en naaien met
# knippen en naaien met burda
#
#
#
# „het sctence fiction universum",
# het science fiction universum
#
#
#
# zaken deed met japan,
# zaken doen met japan
#
#
#
# 2 kwartjes voor kaarsen,
# twee kwartjes voor kaarsen
#
#
#
# leonidas —
# leonidas-prijscourant 1913
#
#
#
# de helden van. de highway
# de helden van de highway
#
#
#
# „elizabeth r,
# elizabeth r.
#
#
#
# zeo mij waar de bloemen zijn.
# zeg mij waar de bloemen zijn
#
#
#
# leer mij de naatschappij kennen.
# leer mij de maatschappij kennen
#
#
#
# hapkes en kleine gerechten;
# hapjes en kleine gerechten
#
#
#
# „gezondheidsaids voor 50-plussers",
# gezondheidsgids voor 50-plussers
#
#
#
# - hereniging en
# hereniging en afrekening
#
#
#
# - „lady
# lady brandon
#
#
#
# „praktijk handboek
# praktijk-handboek kunststoffen
#
#
#
# - met het licht van jouw ogen .
# met het licht van jouw ogen  zegen mij
#
#
#
# victorio en albert.
# victoria en albert
#
#
#
# „wraak als compas",
# wraak als kompas
#
#
#
# „de amsterdamse koffermoord" vier verhalen van
# de amsterdamse koffermoord en andere verhalen
#
#
#
# waarom? daarom.
# waarom? daarom!
#
#
#
# „astrolo-0« roor honden.
# astrologie voor honden
#
#
#
# * jack london
# jack london omnibus
#
#
#
# - „lawine
# lawine express
#
#
#
# - „vrije
# vrije vlucht
#
#
#
# de filosofie ran het japanse management
# de filosofie van het japanse management
#
#
#
# — „bonny
# bonny ballads
#
#
#
# „herinneringen aan een mooi meisje
# herinneringen van een mooi meisje
#
#
#
# dors ontdekt zichzelf.
# doro ontdekt zichzelf
#
#
#
# jacollentjes kleine wereld.
# jacolientjes kleine wereld
#
#
#
# en eit in 15 dagen" -
# slank en fit in 15 dagen
#
#
#
# powezie eenenzestig
# eenenzestig-negenenzestig powezie
#
#
#
# hij was één van ons;
# hij was een van ons
#
#
#
# met betrekkin.; tot jezus;
# met betrekking tot jezus
#
#
#
# de nederlandse poëzie van de twaalfde tol en mei de zestiende eeuw in duizend en enige bladzijden.
# de nederlandse poëzie van de twaalfde tot en met de zestiende eeuw in duizend en enige bladzijden
#
#
#
# kniweltoons.
# knivveltoons
#
#
#
# — de lüscher
# de lüscher kleurentest
#
#
#
# sint
# sint-nicolaas
#
#
#
# „sovjetreclame en propaganda in de jaren twintig". uitgave:
# sovjet reclame en propaganda in de jaren twintig
#
#
#
# „bezuinigen met „er, schaterlach"
# bezuinigen met een schaterlach
#
#
#
# „oosterse geloofsbewegingen in hel westen".
# oosterse geloofsbewegingen in het westen
#
#
#
# „fluitend aan m werk".
# fluitend aan het werk
#
#
#
# - „naar
# naar damaskus
#
#
#
# miï' den ran tijdgenoten en geestverwanten."
# te midden van tijdgenoten en geestverwanten
#
#
#
# gedigle 1958-1973.
# gedigte 1958-1973
#
#
#
# daï licht ran mij.
# dat licht van mij
#
#
#
# het geheim van nei bestaan.
# het geheim van het bestaan
#
#
#
# °p de planken;
# op de planken
#
#
#
# 22 sprookjes, verhalen en fabels
# tweeëntwintig sprookjes, verhalen en fabels
#
#
#
# marx contra de stische ideologen.
# marx contra de marxistische ideologen
#
#
#
# de zevei. slapers,
# de 7 slapers
#
#
#
# — op
# zienswijze op
#
#
#
# - het matchboek
# het matchboek karpov-kortsjnoj
#
#
#
# maria dermoüt
# maria dermoût
#
#
#
# planten en dieren „hajjbritters
# halbritters dieren- en plantenwereld
#
#
#
# „de ark in. de branding"
# de ark in de branding
#
#
#
# „jehovah's getuige, mag ik ook wat
# jehovah's-getuige, mag ik ook wat zeggen?
#
#
#
# geert dammers op
# geert dammers trilogie
#
#
#
# — dagboek
# dagboek 1931-1934
#
#
#
# kaleidoseopisch.
# kaleidoscopisch
#
#
#
# - gedichten:
# moderne gedichten
#
#
#
# j. plomp, de synode. lang zal
# de synode. lang zal ze leven!
#
#
#
# op de vrouw ! in
# de vrouw in de middenleeftijd
#
#
#
# „harleqnin & "co".
# harlequin & co.
#
#
#
# „de fatale beslis,,.
# de fatale beslissing
#
#
#
# duvelstoeiager.
# duvelstoejager
#
#
#
# norman manea: leergeld. verhalen,
# leergeld en andere verhalen
#
#
#
# groenteteelt en bemesting —
# biologische groenteteelt en bemesting
#
#
#
# 'en dan nu... de radio'
# en dan nu de radio!
#
#
#
# -*. meesters der vertelkunst uit de
# meesters der vertelkunst uit de d.d.r.
#
#
#
# „lichaam en antilichaam."
# lichaam & antilichaam
#
#
#
# voor een hond". na
# losgeld voor een hond
#
#
#
# „het materese mysterie",
# het matarese mysterie
#
#
#
# i)e renegaat.
# de renegaat
#
#
#
# uit het latijn vertaalde middelneder- undae novellen.
# twee uit het latijn vertaalde middelnederlandse novellen
#
#
#
# van de transistor en zijn
# de transistor en zijn toepassingen
#
#
#
# „voegend jaar in jeruzalem".
# volgend jaar in jeruzalem
#
#
#
# * leni saris
# leni saris omnibus
#
#
#
# - „een
# een feestdroom
#
#
#
# boyd-..geujoon een beste kerel".
# gewoon een beste kerel
#
#
#
# de beste science fictionverhalen van meulenhoff
# de beste science fiction-verhalen van meulenhoff
#
#
#
# ★ de beste verhalen van
# de beste verhalen van kishon
#
#
#
# oude meneer mundstock
# meneer theodor mundstock
#
#
#
# verbeeld uertrouuien;
# verbeeld vertrouwen
#
#
#
# later het venlo-incident
# het venlo incident
#
#
#
# - „de burger
# de burger voorbij
#
#
#
# - „rode
# rode granaat
#
#
#
# - „schone leien i '"'''
# schone leien zijn er niet
#
#
#
# „hel grote boek met de heerlijkste kookrecepten",
# het grote boek met de heerlijkste kookrecepten
#
#
#
# het laatst/ hoofdstuk;
# het laatste hoofdstuk
#
#
#
# ..de hondenpla>
# de hondenplaneet
#
#
#
# i voor moeder:
# monument voor moeder
#
#
#
# — de nieuwe kuisheid (en andere bedenkingen tegen de feministische
# de nieuwe kuisheid en andere bedenkingen tegen de feministische beweging
#
#
#
# met artikelen over emancipatie en homoseksualiteit. 308
# homojaarboek.dl. 1. artikelen over emancipatie en homoseksualiteit
#
#
#
# ..als ik hitler ' an overleven".
# als ik hitler maar kan overleven
#
#
#
# - „mannen en
# mannen en sex
#
#
#
# de secularisatie f
# politiek en secularisatie
#
#
#
# u voor de kinderen. de
# wagt u voor de kinderen
#
#
#
# doodsstrijd op voorspoed
# doodstrijd op voorspoed
#
#
#
# „levenslang en historisch monument",
# levensgang en historisch moment
#
#
#
# - „de g-plek" en andere recente ontdekkingen op het gebied van de
# de g-plek en andere recente ontdekkingen op het gebied van de seksualiteit
#
#
#
# - „museumboek voor
# museumboek voor noord-brabant
#
#
#
# - „schip zonder
# schip zonder haven
#
#
#
# „man in oor,
# man in oorlog
#
#
#
# beste van rog ttt simons in londen.
# de beste van roger simons in londen
#
#
#
# - „pension
# pension \eureka\
#
#
#
# oor: 'oor's eerste nederlandse pop-encyclopedie',
# oor's eerste nederlandse pop encyclopedie
#
#
#
# „verliefd en verloren".
# verliefd & verloren
#
#
#
# (red.): „zwarte beertjes crime-jaarboek 2".
# zwarte beertjes crime jaarboek 2
#
#
#
# ,mah oehakba",
# allah oehakba
#
#
#
# een lust roor het oog.
# een lust voor het oog
#
#
#
# een „hulp-in-noodgids"
# elseviers hulp-in-noodgids
#
#
#
# de familie ashton. uit
# de familie ashton trilogie
#
#
#
# „schaatsseizoen '86-'b7".
# schaatsseizoen '86-'87
#
#
#
# zwol: als de wijken",
# als de nevels wijken
#
#
#
# „verlicht uto reumatiek en arthritis".
# verlicht uw reumatiek en arthritis
#
#
#
# bloemlezing korte verhalen uit de jaren
# korte verhalen uit de jaren zeventig
#
#
#
# je bent een hegbeest;
# je bent een liegbeest
#
#
#
# mijn .ponde in het dodenrijk,
# mijn sponde in het dodenrijk
#
#
#
# ★ lasschuit's — officieel adresboek van hotels, motels
# lasschuit's officieel adresboek hotels motels en restaurants innederland
#
#
#
# een reviert man.
# een gevierd man
#
#
#
# het una rond mao
# het land rond mao
#
#
#
# hel motief
# het motief
#
#
#
# „de laatste tan-9o
# de laatste tango
#
#
#
# „kapitein wichaehs",
# kapitein michalis
#
#
#
# science ïction-verhalen. pocket,
# science fiction verhalen
#
#
#
# „de cock en de "ansende dood",
# de cock en de dansende dood
#
#
#
# cock en de |et lijk aan de kerkmuur".
# de cock en het lijk aan de kerkmuur
#
#
#
# - het grote
# het grote canonboek
#
#
#
# barbaro.
# barbara
#
#
#
# f 9.75. -_- informatie in woord en beeld.
#  informatie in woord en beeld over de middeleeuwen
#
#
#
# f 9.75. -_- informatie in woord en beeld.
#  informatie in woord en beeld over de middeleeuwen
#
#
#
# zeg maar dag met je voetje
# zeg maar dág met je voetje
#
#
#
# „zo leefden de impressionisten. van' de salon des réfusés tot de dood van manet 1863-1883".
# zo leefden de impressionisten van de salon des refuses tot de dood van manet 1863-1883
#
#
#
# de tekenaar ]o spier. nijgh
# de tekenaar jo spier (1900-1978)
#
#
#
# bossenbroek: harderwijk als militaire en de geschiedenis van 4 divisie
# harderwijk als militaire stad en de geschiedenis van 4 divisie
#
#
#
# hjj derde huwelijk.
# het derde huwelijk
#
#
#
# - wat kunnen wij van rijke mensen
# wat kunnen wij van rijke mensen leren?
#
#
#
# penelope van de „polyanthe"
# penelope van de 'polyanthe'
#
#
#
# de zonen van ragusa.
# de zonen van ragousa
#
#
#
# dag sonder einde
# dag zonder einde
#
#
#
# wie treurt om mary smitta?
# wie treurt om mary smith?
#
#
#
# „sloot op den trommele."
# slaat op den trommele
#
#
#
# —tarantulo.
# tarantula
#
#
#
# aquariumjoto's moken
# aquariumfoto's maken
#
#
#
# (tijloos (co.-ihicum autumnale)
# herfsttijloos (colchicum autumnale)
#
#
#
# 'het allround motorhandboek'
# het all-round motorhandboek
#
#
#
# het postume werk van een levende
# het posthume werk van een levende
#
#
#
# - „alles is
# alles is heimwee
#
#
#
# atiet meer aan denken.
# niet meer aan denken
#
#
#
# ode va de zee
# ode van de zee
#
#
#
# — wankel
# wankel bezit
#
#
#
# j. b. van
# j.b. van heutsz
#
#
#
# homerus. odyssee.
# homèros' odyssee
#
#
#
# „de vijfde ™('er
# de vijfde ruiter
#
#
#
# - het dansmeisje en °e.'indepater.
# het dansmeisje en de lindepater
#
#
#
# „uit naam de aartsengel". de
# uit naam van de aartsengel
#
#
#
# „cultuurtechnicshe ontwikkelingen in de friese wouden na 1918"
# cultuurtechnische ontwikkelingen in de friese wouden na 1918
#
#
#
# ..pa.sta".
# pasta
#
#
#
# dautd versus goliath.
# david versus goliath
#
#
#
# „niet schieten... we are dutch!"
# niet schieten  we are dutch!
#
#
#
# nachtelijk spel - de verhalen
# nachtelijk spel en andere verhalen
#
#
#
# 'piëta'
# pieta
#
#
#
# bewust ~,, onbewust
# bewust en onbewust
#
#
#
# „de dreiging van dr islam".
# de dreiging van de islam
#
#
#
# ' ren in december".
# samen musiceren in december
#
#
#
# dam - ..mag ik de
# mag ik de afdeling voorzienigheid?
#
#
#
# luitebol'.
# luilebol!
#
#
#
# elseviers coekual- en longtirinkboek.
# elsevier cocktail- en longdrinkboek
#
#
#
# leonabd: in spin — opnieuw gaat de bocht
# in spin - opnieuw gaat de bocht in
#
#
#
# het dagboek in de sneeuw treft men verhalen
# het dagboek in de sneeuw en andere griezelverhalen
#
#
#
# eerc grote taak op onyx
# een grote taak op onyx
#
#
#
# het oog ran de naald.
# het oog van de naald
#
#
#
# anderen volle literaire leven.
# het volle literaire leven
#
#
#
# over rené. gysen
# over rené gysen
#
#
#
# christlaan, leven en lijden van een charlatan.
# christiaan, leven en lijden van een charlatan
#
#
#
# en romantische verhalen vraagt. de bundel „de romantische koster van ranö"
# de romantische koster van rånö en andere verhalen van de scheren
#
#
#
# - „de gebroken
# de gebroken vrouw
#
#
#
# „vtagprotocol,
# vlagprotocol
#
#
#
# geïllustreerde internationale weefdictionaire".
# geïllustreerde internationale weefdictionnaire
#
#
#
# lijk ambt in discussie
# kerkelijk ambt in discussie
#
#
#
# - „de scharlaken
# de scharlaken zeilen
#
#
#
# * prentbriefkaarten katalogus nederland
# katalogus prentbriefkaarten nederland 1981
#
#
#
# - ontmoeting met jan
# ontmoeting met jan swammerdam
#
#
#
# - abc. ruiter rijd je
# abc ruiter rijd je mee?
#
#
#
# -..mama is de liefste ean de hele wereld."
# mama is de liefste van de hele wereld
#
#
#
# kritisch akkoord '77
# kritisch akkoord 1977
#
#
#
# rout van de dode zee heet
# het zout van de dode zee
#
#
#
# dodenraen
# dodenrace
#
#
#
# 'de kattenkoninging en andere verhalen'
# de kattenkoningin en andere verhalen
#
#
#
# de cd gids
# cd gids jazz
#
#
#
# de verloren wereld van de familie berberovic
# de verloren wereld van de familie berberović
#
#
#
# „numerologie", werkboek.
# numerologie werkboek
#
#
#
# „jonge, jonge, jflt smaakt",
# jonge jonge, dat smaakt!
#
#
#
# „straatnadelieven".
# straatmadelieven
#
#
#
# „postduiven" is
# handboek postduiven
#
#
#
# requiem roor een spaanse boer.
# requiem voor een spaanse boer
#
#
#
# ..nicaragua '*
# nicaragua '78
#
#
#
# boven alle si
# boven alle schuld
#
#
#
# bekentenis op sterk wsttr.
# bekentenis op sterk water
#
#
#
# nagelaten snikken van plet paaltjes.
# nagelaten snikken van piet paaltjens
#
#
#
# charles waterton 17x2-1865.
# charles waterton 1782-1865
#
#
#
# zoet en hartig gebak.
# zoet & hartig gebak
#
#
#
# van het heelal" - nu
# elseviers encyclopedie van het heelal
#
#
#
# „standplaats euromi',
# standplaats europa
#
#
#
# „ceremonie n rood".
# ceremonie in rood
#
#
#
# „de cock en de 'ervende wandelaar",
# de cock en de stervende wandelaar
#
#
#
# „het geheim °n de laatste letter",
# het geheim van de laatste letter
#
#
#
# „de cock en de '°rgvuldige moordenaar",
# de cock en de zorgvuldige moordenaar
#
#
#
# „de tijdmachine en [_oere verhalen",
# de tijdmachine en andere verhalen
#
#
#
# „d. knetterende schedels"
# de knetterende schedels
#
#
#
# „gedichten 1954--1968"
# gedichten 1954-1968
#
#
#
# onderhouden en - repareren
# antiek onderhouden en repareren
#
#
#
# de ware : elvis
# de ware elvis presley
#
#
#
# agg, moeder, wat nu?"
# agg moeder, wat nu?
#
#
#
# aan het oude perzië
# het wonder van perzië
#
#
#
# „china met een g(l)imlac
# china met een gl-rimlach
#
#
#
# 184 manieren om een kraanleertje te vervangen en andere praktische tips voor huistuin-en-keukenklussen.
# 184 manieren om een kraanleertje te vervangen en andere praktische tips voor huis-tuin-en-keukenklussen
#
#
#
# zlata filipovic: het dagboek van
# het dagboek van zlata filipović
#
#
#
# * het grote knutselboek
# het tweede grote knutselboek
#
#
#
# - de
# de mensentuin
#
#
#
# 'e opdracht
# de opdracht
#
#
#
# regan en de manhattan-zaak,
# regan en de manhattanzaak
#
#
#
# - de storm. verhalen van
# de storm en andere verhalen
#
#
#
# „de bark sebastiaan pot, en de laatste gloriedagen van de grote zeilvaart".
# de bark 'sebastiaan pot' en de laatste gloriedagen van de grote zeilvaart
#
#
#
# uit 'noord-sumatra in oorlogstijd.
#  noord sumatra in oorlogstijd
#
#
#
# de erfenis vau oompje ho
# de erfenis van oompje ho
#
#
#
# carter: „alles op
# alles op alles!
#
#
#
# — de
# de onverzoenlijken
#
#
#
# kritisch akkoord van
# kritisch akkoord 1980
#
#
#
# bikker: helaai.' de holen der menschen;
# ' helaas! de holen der menschen'
#
#
#
# con van der sluys
# corn. van der sluys
#
#
#
# „de man die jonden kocht",
# de man die londen kocht
#
#
#
# „de groene 192
# de groene dood
#
#
#
# „steeds weer* verboer",
# steeds weer klaverboer
#
#
#
# „de dame 'on duke street".
# de dame van duke street
#
#
#
# 7an baby tot kleuter.
# van baby tot kleuter
#
#
#
# mustieke wijsheid en universele kennis".
# mystieke wijsheid en universele kennis
#
#
#
# - de wereld ging driemaal
# de wereld ging driemaal onder
#
#
#
# liologische atlas van de nederlandse roofvogels.
# ecologische atlas van de nederlandse roofvogels
#
#
#
# :/>. m en dt visserij van arnemuiden
# de hoogaars en de visserij van arnemuiden
#
#
#
# van de russische literatuur in
# geschiedenis van de russische literatuur
#
#
#
# „officieren acnter prikkeldraad 1940-1945".
# officieren achter prikkeldraad 1940-1945
#
#
#
# irene,
# irène
#
#
#
# tinfcerbelle.
# tinkerbelle
#
#
#
# jongenstransistorboek
# jongens-transistorboek
#
#
#
# „fela j".
# fela j.
#
#
#
# „de ballade van het trieste café en spiegelingen in een gouden oog".
# de ballade van het trieste café & spiegelingen in een gouden oog
#
#
#
# het land, waar het kerstfeest begon".
# het land waar het kerstfeest begon
#
#
#
# saddam hussein
# saddam hoessein
#
#
#
# verf en bederf.
# verf en verderf
#
#
#
# informatie en intelligentie,
# informatie & intelligentie
#
#
#
# ohra grootmeestertoernooi amsterdam 1990, door
# 9e ohra grootmeester toernooi amsterdam
#
#
#
# „echte yupptes zijn geen yuppies".
# echte yuppies zijn geen yuppies
#
#
#
# meijer:.mijn naam is gar
# mijn naam is garrigue
#
#
#
# „de toereid van anton pieck".
# de wereld van anton pieck
#
#
#
# - „langer vitaal
# langer vitaal blijven
#
#
#
# - ..lidia het
# lidia het zigeunermeisje
#
#
#
# ..het beste patienceboek i-oor beginners.'
# het beste patienceboek voor beginners
#
#
#
# — compagnie
# compagnie \c
#
#
#
# 'ster'
# ster!
#
#
#
# 'uit het schetsboek van cor"elis jetses'
# uit het schetsboek van cornelis jetses
#
#
#
# „waren de goden kosmonauten":
# waren de goden kosmonauten?
#
#
#
# een hollandse durpssamenleving in de late achltiendt ne
# een hollandse dorpssamenleving in de late achttiende eeuw
#
#
#
# — hefte zu hegels
# hefte zu hegels dialektik
#
#
#
# - „razernij in
# razernij in harlem
#
#
#
# babylon aan de rhöne.
# babylon aan de rhône
#
#
#
# de prisma-belastingeids
# prisma belastinggids
#
#
#
# het boekje „aftrekposten inkomstenen vermogensbelasting" van
# aftrekposten bij de inkomsten- en vermogensbelasting
#
#
#
# de boor. tagebuchblaetter aus den jahren 1938-1945.
# tagebuchblätter aus den jahren 1938 - 1945
#
#
#
# partei und staat im dritten reich;
# kirche und staat im dritten reich
#
#
#
# wieiuel zukunft hat unsere vergangenheit?;
# wieviel zukunft hat unsere vergangenheit?
#
#
#
# — massage voor
# massage voor iedereen
#
#
#
# ..eiseriers medisch gezinsboek".
# elseviers medisch gezinsboek
#
#
#
# 'earnewald van doe nei no'
# earnewâld fan doe nei no
#
#
#
# noordamerikaanse indianensproókjes,
# noordamerikaanse indianensprookjes
#
#
#
# slak" en „amalia slak trekt
# amalia slak trekt erop uit
#
#
#
# volgende zaak
# volgende zaak!
#
#
#
# visser—roosendaal
# visser-roosendaalomnibus
#
#
#
# 477). literair akkoord
# literair akkoord 3
#
#
#
# — amy. de
# amy de ontembare
#
#
#
# sylvla bij de film.
# sylvia bij de film
#
#
#
# zomeravond, halfelf.
# zomeravond halfelf
#
#
#
# cyberpunks
# cyberpunksf
#
#
#
# - de moorddadige
# de moorddadige motormaniak
#
#
#
# 'de blau■p wezen van leeuwarden
# de blauwe wezen van leeuwarden
#
#
#
# harald stroucken. bi
# afzender harald stroucken
#
#
#
# de n.v. dopiflex.
# de nv dopiflex
#
#
#
# — dagboek
# dagboek 1878-1923
#
#
#
# storen noor de zon.
# staren naar de zon
#
#
#
# de wedstrijdregels in de praktiik 1989-1992,
# de wedstrijdregels in de praktijk, 1989-1992
#
#
#
# ln het hol van de leeuw.
# in het hol van de leeuw
#
#
#
# toernooiboekje. 'kostgangers van caïssa'
# de kostgangers van caïssa
#
#
#
# de gebroeders blco.
# de gebroeders rico
#
#
#
# polen, waar wacht ge op
# polen waar wacht je op
#
#
#
# de taal waarmee wu leven.
# de taal waarmee wij leven
#
#
#
# onze vrijheid moest duur u-orden betaald.
# onze vrijheid moest duur worden betaald
#
#
#
# en per slot van
# per slot van rekening
#
#
#
# om landbouwpaard, vroeger, nu en later.
# ons landbouwpaard vroeger, nu en later
#
#
#
# - groepsanalytische
# groepsanalytische psychotherapie
#
#
#
# „augustus is een kwade maan
# augustus is een kwade maand
#
#
#
# in 'een tafel voor
# een tafel voor een
#
#
#
# het rosé boekje van de beddrijfveerleidet
# het rose boekje van de bedrijfveerleider
#
#
#
# — de doden weten
# de doden weten niets
#
#
#
# hier mijn hand en daar je wang
# hier mijn hand en dáár je wang
#
#
#
# een kleine jongen en zn beer,
# een kleine jongen en z'n beer
#
#
#
# kwarualzaad. en 37 andere verhalen
# kwartelzaad en 37 andere verhalen
#
#
#
# - gevangene van de
# gevangene van de tijd
#
#
#
# ..eén bijbel, twee gedachten."
# één bijbel, twee gedachten
#
#
#
# confuclus.
# confucius
#
#
#
# de voorsokratlci
# de voorsokratici
#
#
#
# cehnes grote oorlog,
# célines grote oorlog
#
#
#
# de bom moet bars
# de bom moet barsten
#
#
#
# jonghe — hitler en het politieke lot t*an bel-ftë (1940-1944).
# hitler en het politieke lot van belgie (1940 - 1944)
#
#
#
# de literaire
# literaire essays
#
#
#
# en kritieken
# verspreide kritieken
#
#
#
# ... antiek
# antiek kopen
#
#
#
# hommes novi
# homines novi
#
#
#
# huis in vuur. uit
# dit huis in vuur
#
#
#
# ★ paul erdman: „handboek voor de
# paul erdman's handboek voor de belegger
#
#
#
# „de prijs van hel bloed", de
# de prijs van het bloed 1584-1625
#
#
#
# „het oslerman weekend".
# het osterman weekend
#
#
#
# het siclllaanse avontuur.
# het siciliaanse avontuur
#
#
#
# „en zyn spoor verdween,"
# en zijn spoor verdween
#
#
#
# — de
# de druivenpers
#
#
#
# de oorlog met lugurtha.
# de oorlog met iugurtha
#
#
#
# dit dwangbeste' van mens en god."
# dit dwangbestel van mens en god
#
#
#
# norris mcwhirter: „het groot guinness record
# het groot guinness record boek 1986
#
#
#
# — de
# de sirkelbewoners
#
#
#
# ruiter* van morgen.
# ruiters van morgen
#
#
#
# „rondom de familiedis"
# rondom de familie-dis
#
#
#
# „het lijk- rekent af"
# het lijk rekent af
#
#
#
# halbertsma
# halbertsma-bibliografy
#
#
#
# o, o, die wolkewietje toch!
# o! o, die wolkewietje toch!
#
#
#
# a uit het oerwoud;
# alja uit het oerwoud
#
#
#
# zeven roze biggetjes;
# zeven rose biggetjes
#
#
#
# prins uierhart in zijn strijd tegen de hunnen.
# prins ijzerhart in zijn strijd tegen de hunnen
#
#
#
# de olifantensag.
# de olifantenslag
#
#
#
# e honden bijten de laatsten.
# de honden bijten de laatsten
#
#
#
# ttvee dagreizen,
# twee dagreizen
#
#
#
# * reisgids voor mallorca -
# van goor's reisgids voor mallorca
#
#
#
# in 'hyperion' van de
# de ondergang van hyperion
#
#
#
# - „claudius de
# claudius de god
#
#
#
# „niets om "et lijf".
# niets om het lijf
#
#
#
# rendez-voua met de dood
# rendez-vous met de dood
#
#
#
# het geheim van arsène 1*!?,
# het geheim van arsène lupin
#
#
#
# boekje open - over centralisatie in de uitgeverij ten behoeve van de
# over centralisatie in de uitgeverij ten behoeve van de streek(taal)culturen in noordoost-nederland
#
#
#
# - f-i [drillenmaari in winschoot;
# noar 't adrillenmaart in winschoot
#
#
#
# kunst om jong te blijven".
# de kunst jong te blijven
#
#
#
# tuinbouwgids 196
# tuinbouwgids 1964
#
#
#
# __._srs_ïï.«! engels raaigras'
# als engels raaigras
#
#
#
# ben ik (eigenlijk) wel links genoeg
# ben ik eigenlijk wel links genoeg?
#
#
#
# seitenblicfce auf europa.
# seitenblicke auf europa
#
#
#
# des 20. jahrhunderts —
# politiker des 20. jahrhunderts
#
#
#
# geen twyfel, dat de sheik werkelijk de chef
# mijn chef de sheik, mijn chef de sheik
#
#
#
# plantenziekten in de tuinbouw.
# planteziekten in de tuinbouw
#
#
#
# plantkunde voor tuinbouwscholen. derde
# plantkunde voor de tuinbouwscholen
#
#
#
# dialecten in. nederland;
# dialecten in nederland
#
#
#
# jaarboek overijssel
# overijssel '69
#
#
#
# — abc voor de
# abc voor de hondeliefhebber
#
#
#
# „het erf te cleopatra."
# het erf te cleopátra
#
#
#
# engel en de blinde man."
# de engel en de blindeman
#
#
#
# de droom die geen werkelijkheid mocht worden'.ln de
# huttonia, de droom die geen werkelijkheid mocht worden
#
#
#
# myn volk en myn leven.
# mijn volk en mijn leven
#
#
#
# „sierduiven ln de lage landen"
# sierduiven in de lage landen
#
#
#
# almanak voor beleggers m.
# kleine beleggers almanak 1970
#
#
#
# vandeberg.
# vandenberg
#
#
#
# - „vaselientjes
# vaselientjes kleuterpraat
#
#
#
# - ..elseviers sfomnibus".
# elseviers sf omnibus
#
#
#
# „verstoot gij wat gij leest?"
# verstaat gij wat gij leest?
#
#
#
# .folemologie".
# polemologie
#
#
#
# romero: „simone beauvoir,
# simone de beauvoir
#
#
#
# „de sowjet-unie zien..."
# \de sovjet-unie zien\
#
#
#
# „baaien droefheid".
# baalen droefheid
#
#
#
# „een teken van leven".
# een teken ten leven
#
#
#
# - ik heb je zoveel te
# ik heb je zoveel te vertellen
#
#
#
# ïvroren vuurwerk.
# bevroren vuurwerk
#
#
#
# juffrouw stolk. en andere verhalen.
# juffrouw stolk en ander verhalen
#
#
#
# de wijsbegeerte van de ?»st» eeuw.
# de wijsbegeerte van de 20e eeuw
#
#
#
# „en de hof der lusten" brengt
# ghislaine en de hof der lusten
#
#
#
# zelf uw meubels voor de kinderkamer;
# maak zelf meubels voor de kinderkamer
#
#
#
# „dr. helen keiler":
# dr. helen keller
#
#
#
# het geheim van de tweezusjes. ult
# het geheim van de twee zusjes
#
#
#
# moord °p een negatlet.
# moord op een negatief
#
#
#
# het geheim van het meisje ln maillot.
# het geheim van het meisje in maillot
#
#
#
# „de imitators"
# de mimitators
#
#
#
# elsevlers encyclopedie van de archeologie.
# elseviers encyclopedie van de archeologie
#
#
#
# ,jloeveel zijn er nog over?".
# hoeveel zijn er nog over?
#
#
#
# jaarboek voor de geschiedenis van socialisme en arbeidersbeweging in nederland 1978.
# jaarboek voor de geschiedenis van socialisme en arbeidersbeweging in nederland 1979
#
#
#
# indiengesprache
# indiengespräche
#
#
#
# „de real van het geloof";
# de realiteit van het geloof
#
#
#
# „kennut zijn dat ik v kan?"
# kennut zijn dat ik u kan?
#
#
#
# statistisch overzicht van
# statistisch overzicht 1959
#
#
#
# nachttooud
# nachtwoud
#
#
#
# het zelfgeu-ilde einde van oude mensen.
# het zelfgewilde einde van oude mensen
#
#
#
# „anti-
# anti-memoirs
#
#
#
# * ." land van oc".
# uit het land van oc
#
#
#
# elsevlers encyclopedie van de muziek.
# elseviers encyclopedie van de muziek
#
#
#
# paddlngton brengt uitkomst
# paddington brengt uitkomst
#
#
#
# nu kon iedereen het weten
# nu kan iedereen het weten
#
#
#
# - de
# de getuige
#
#
#
# dit boek gaat over jezus-
# dit boek gaat over jesus
#
#
#
# de daden van 'de doorluchtighste zee-helden en ontdeckers deser eeuwen' en
# leeven en daden der doorluchtighste zee-helden en ontdeckers van landen,deser eeuwen
#
#
#
# van vrijheidsstrijder tot vrede.
# van vrijheidsstrijd tot vrede
#
#
#
# „zeven heerlijkhed
# zeven heerlijkheden
#
#
#
# malgret en het spook.
# maigret en het spook
#
#
#
# de pijp van malgret.
# de pijp van maigret
#
#
#
# kluwers belastinggids.
# kluwer belastinggids
#
#
#
# — geluk is als een tere
# geluk is als een tere bloem
#
#
#
# «c heb goddank twee goede longen.
# ik heb goddank twee goede longen
#
#
#
# „het syndikaat".
# het syndicaat
#
#
#
# „fhiiten naar de overkant".
# fluiten naar de overkant
#
#
#
# * de charge van de
# de charge van de muizenbrigade
#
#
#
# f. oltmans- „het slot loevestein".
# het slot loevestein in 1570
#
#
#
# wie was edgar allen?
# wie was edgar allan?
#
#
#
# e t bruidslied. (alsmede: vlaggen in stad en
# het bruidslied alsmede, vlaggen in stad en haven
#
#
#
# tachtig jaar nederland. geb,
# tachtig jaar nederland 1880-1960
#
#
#
# „kapitein bligh en fletcher christian".
# kapitein bligh & fletcher christian
#
#
#
# who in vvhatland. ing.,
# who's who in whatland
#
#
#
# geworden een eeuw middelbaar-onderwijswet herdacht. (1863—1963).
# een eeuw middelbaar onderwijswet herdacht, 1863-1963
#
#
#
# de aegeïsche wereld, volgens het oudste griekse schrift.
# de aegeïsche wereld volgens het oudste griekse schrift
#
#
#
# 'alles over managementstests'. dat
# alles over management tests
#
#
#
# e.a.: het groot guiness record book.
# het groot guinness record boek 1991
#
#
#
# waarom run een walvis?
# waarom van een walvis?
#
#
#
# - chinese
# chinese gedichten
#
#
#
# - „feminisme voor vrouwen en
# feminisme voor vrouwen en mannen
#
#
#
# fen dichter op het binnenhof.
# een dichter op het binnenhof
#
#
#
# „zw logïk der sozialwissenschaften"
# zur logik der sozialwissenschaften
#
#
#
# ,aufsatze und reden"
# aufsätze und reden
#
#
#
# de raadselachuge wereld van de droom.
# de raadselachtige wereld van de droom
#
#
#
# de oprn poort.
# de open poort
#
#
#
# vijftien jaar boven
# vijftien jaar boven-digoel
#
#
#
# - de -
# winnie de poeh
#
#
#
# het groot leeroversboek.
# het groot zeeroversboek
#
#
#
# blz., ƒ27,50. 'het naakte leven. verhalen.
# het naakte leven en andere verhalen
#
#
#
# ~250 caravanlips -
# 250 caravan tips
#
#
#
# van het nieuwbjj liefdegebod
# ethiek van het liefdegebod
#
#
#
# „en ik dan".
# en ik dan?
#
#
#
# — de angst der
# de angst der patriotten
#
#
#
# de elektrotechniek
# elektrotechniek iii
#
#
#
# landhouwdierkunde.
# landbouwdierkunde
#
#
#
# letters ln kruissteek.
# letters in kruissteek
#
#
#
# nederland-se molens in oude ansichten
# nederlandse molens in oude ansichten
#
#
#
# puzzelwoordenbnrk.
# puzzelwoordenboek
#
#
#
# het duivelsklooster. en andere verhalen.
# het duivelsklooster en andere verhalen
#
#
#
# psychologie voor ledereen.
# psychologie voor iedereen
#
#
#
# — sesam-encyclopedie van de seksualiteit
# sesam encyclopedie van de seksualiteit
#
#
#
# europa in de de
# europa in de universiteit
#
#
#
# voor de statistiek,
# statistiek voor m.b.a.
#
#
#
# pannekoek - memoires. van
# memoires van yvo pannekoek
#
#
#
# de organisatiestructuur van het bedrüf.
# de organisatiestructuur van het bedrijf
#
#
#
# llvlngstone de zwerver.
# livingstone, de zwerver
#
#
#
# het huif ln het poeh.hoekje.
# het huis in het poeh-hoekje
#
#
#
# jan woont ln suriname.
# jan woont in suriname
#
#
#
# oost indië
# oost-indië gespiegeld
#
#
#
# .geniaal., maar met te korte beentjes11.
# geniaal maar met te korte beentjes
#
#
#
# „goede vaarf
# goede vaart
#
#
#
# breng de bismarck tot zinken.
# breng de bismarck tot zinken!
#
#
#
# — de
# de leeuwekuil
#
#
#
# willem teil,
# willem tell
#
#
#
# „bekooriyk en behoor
# bekoorlijk en behoorlijk
#
#
#
# behandeling van de belastingwetten.
# praktische behandeling van belastingwetten
#
#
#
# man en vrouw, vóór en in het huwelijk,
# man en vrouw vóór en in het huwelijk
#
#
#
# de misdaad van giovanni venturl.
# de misdaad van giovanni venturi
#
#
#
# de huisvesting van vollèrevogels.
# de huisvesting van volièrevogels
#
#
#
# kluwers belastinggids
# kluwer belastinggids
#
#
#
# marx' leren en werk.
# marx' leven en werk
#
#
#
# „onbekend lerland".
# onbekend ierland
#
#
#
# ..schrale troost voor magere jaren"
# schrale troost in magere jaren
#
#
#
# — „de
# de poedel
#
#
#
# schreven 'huwelijksboek' juliana en bernhard „50 gouden
# het gouden huwelijk van juliana en bernhard
#
#
#
# opkomst en onderga ng van het derde
# opkomst en ondergang van het derde rijk
#
#
#
# = matthias
# matthias grünewald
#
#
#
# „het geheim van de incaspeer"
# het geheim van de inca-speer
#
#
#
# wie geeft m e
# wie geeft me jatmous?
#
#
#
# ,^hitlers mem kampf"
# hitlers mein kampf
#
#
#
# de bijbel zegt over de „bekoring"
# de bijbel over mensen in bekoring
#
#
#
# e verkenningen;
# bijbelse verkenningen
#
#
#
# lagerlöf, het meisje _v„an^,.e, veenhoeve.
# het meisje van de veenhoeve
#
#
#
# leren paardrüden.
# leren paardrijden
#
#
#
# ★ reinaart de
# reinaart de vos
#
#
#
# ijslandse
# ijslanders
#
#
#
# tips in kort bestek";
# diepvries-tips in kort bestek
#
#
#
# - „modern dieet, bij te hoge bloeddruk en
# modern dieet bij te hoge bloeddruk en hartziekten
#
#
#
# verztoegen verleden.
# verzwegen verleden
#
#
#
# n» boog der sterken.
# de boog der sterken
#
#
#
# jorissa wint het -jelnk.
# jorissa wint het geluk
#
#
#
# „het vluchtvit*«",
# het vluchtvirus
#
#
#
# — mijn. mes, mijn vriend.
# mijn mes is mijn vriend
#
#
#
# fynsten üt fryske groun,
# fynsten út fryske groun
#
#
#
# „jacht-schade".
# jachtschade
#
#
#
# „de zin van ziek
# de zin van ziekzijn
#
#
#
# aan god die miin jeugd verblijdt.
# aan god die mijn jeugd verblijdt
#
#
#
# „de „mozart" vertrekt om 9.12"
# de 'mozart' vertrekt om 9.12
#
#
#
# tips voor de kruidentuin" —
# 300 tips voor de kruidentuin
#
#
#
# deseartes.
# descartes
#
#
#
# rodolphus agrlcola.
# rodolphus agricola
#
#
#
# antonl van leeuwenhoek. alsmede zijn voornaamste ontdekkingen.
# antoni van leeuwenhoek en zijn voornaamste ontdekkingen
#
#
#
# oefconomisclier kalkül und eiaentumsformen
# ökonomischer kalkül und eigentumsformen
#
#
#
# gegen den dogmatismus in der arbeitersbewegung.
# gegen den dogmatismus in der arbeiterbewegung
#
#
#
# texte zu technokratiediskussion.
# texte zur technokratiediskussion
#
#
#
# le problème de i'vvra linda bok,
# le problème de l'wra linda bok
#
#
#
# 'naar de golf.
# naar de golf!
#
#
#
# — welke
# welke emancipatie?
#
#
#
# — bankrott der
# bankrott der männerherrschaft
#
#
#
# ..wie verder gaat wordt doodgeschoten." de
# wie verder gaat wordt dood geschoten
#
#
#
# z«*«" naar liefde.
# zoekers naar liefde
#
#
#
# scheepvaart ln de oudheid.
# scheepvaart in de oudheid
#
#
#
# ne mens en zijn toekomst.
# de mens en zijn toekomst
#
#
#
# het overrompellntifevaar als vennootschappelijk probleem.
# het overrompelingsgevaar als vennootschappelijk probleem
#
#
#
# der gesellschaft. de
# entschulung der gesellschaft
#
#
#
# japons diagonaal.
# japan diagonaal
#
#
#
# de wereld michael palin: de reis om de wereld in 80
# de reis om de wereld in 80 dagen met michael palin
#
#
#
# uitg. elseviers weekblad! de belasting-almanak
# de belasting-almanak  van elseviers weekblad
#
#
#
# - uit het hart van de winter
# fluiten uit het hart van de winter
#
#
#
# wat niet kon. en andere verhalen.
# wat niet kon en andere verhalen
#
#
#
# „mewio medezeggenschapsraad onderwijs
# memo medezeggenschapsraad onderwijs
#
#
#
# '•etnische groepen in het onderwijs
# etnische groepen en het onderwijs
#
#
#
# lngmar bergman zoekt de sleutel.
# ingmar bergman zoekt de sleutel
#
#
#
# wij sparen ern geleidehond.
# wij sparen een geleidehond
#
#
#
# de kameleon ln de branding.
# de kameleon in de branding
#
#
#
# en bloesemgeur -
# pestdamp en bloesemgeur
#
#
#
# 'jou krijg ik nog welp
# jou krijg ik nog wel!
#
#
#
# volgens cork ■ *
# de wereld volgens cork
#
#
#
# research en 'ethiek.
# research en ethiek
#
#
#
# het christendom ln de 20ste eeuw.
# het christendom in de 20ste eeuw
#
#
#
# leesboek. bestemd voor landbouwscholen en cursussen
# engels leesboek voor landbouwscholen en -cursussen
#
#
#
# sloten, wel verzorgd, goed gekleed.
# wel verzorgd en goed gekleed
#
#
#
# plantenteelt. gewassen voor de
# plantenteelt-gewassen voor de kleigronden
#
#
#
# - alleen gedichten kan ik wonen. lmj
# alleen in mijn gedichten kan ik wonen
#
#
#
# „op weg naar een nieuu» echtscheidingsrecht".
# op weg naar een nieuw echtscheidingsrecht
#
#
#
# charles uarwin, hervormer der biologie.
# charles darwin, hervormer der biologie
#
#
#
# solowjew.
# solowiew
#
#
#
# boeken tv-klassieken:
# tv klassieken
#
#
#
# „de terugkeer van de tij
# de terugkeer van de tijger
#
#
#
# het dier en zij» verschijning.
# het dier en zijn verschijning
#
#
#
# — in feiten en cijfers
# israël in feiten en cijfers
#
#
#
# prisma
# prisma-autogids
#
#
#
# ais je houdt van iemand met een psychische ziekte.
# als je houdt van iemand met een psychische ziekte
#
#
#
# ..en toch niet bl,j".
# en toch niet blij
#
#
#
# spaohetti met stokjes.
# spaghetti met stokjes
#
#
#
# - „de val van bas
# de val van bas p.
#
#
#
# menuboek voor feestelijke etentjes „wina born's
# wina born's menuboek voor feestelijke etentjes
#
#
#
# — albumferskes.
# album ferskes
#
#
#
# blz. dezelfde „heidi en peter".
# heidi en heidi en peter
#
#
#
# een voor de middelbare handelsavondschool met 5-jarige cursus
# bedrijfshuishoudkunde voor de middelbare handelsavondschool met 5-jarige cursus
#
#
#
# mlriam wieland.
# miriam wieland
#
#
#
# * het
# het belasting-abc
#
#
#
# — het leven en de werken van leopold
# het leven en de werken van leopold ii
#
#
#
# —de toereld van het optimisme.
# de wereld van het optimisme
#
#
#
# „de verdwijning van de santa lu
# de verdwijning van de santa lucia
#
#
#
# montesquleu.
# montesquieu
#
#
#
# sir liaac newton.
# sir isaac newton
#
#
#
# ,£oldaatje spelen onder de smaragden gordel".
# soldaatje spelen onder de smaragden gordel
#
#
#
# - kroniek re- keuning.
# kroniek van meester keuning
#
#
#
# eyl, eduard flipse.
# over eduard flipse
#
#
#
# roman voorbijgaande
# voorbijgaande schaduwen
#
#
#
# boek zelfportret als
# zelfportret als legkaart
#
#
#
# appels in het bi,
# appels in het gras
#
#
#
# van het warenhuis bond street
# het warenhuis in bond street
#
#
#
# het brein in cd krabnevel.
# het brein in de krabnevel
#
#
#
# de vikingen van tav ceti.
# de vikingen van tau ceti
#
#
#
# - de lorimer
# de lorimer saga
#
#
#
# orer de leegte in de wereld.
# over de leegte in de wereld
#
#
#
# rige op'e drompel fan de romantyk.
# op 'e drompel fan de romantyk
#
#
#
# maximiliaans ie
# maximiliaan i
#
#
#
# - fundamenteel
# fundamenteel belijden
#
#
#
# nederlandse slreekreeepten".
# oudnederlandse streekrecepten
#
#
#
# nieuw gezinsboek roor /eerst.
# nieuw gezinsboek voor kerst
#
#
#
# „turken horen e f ook
# turken horen er ook bij
#
#
#
# revs, aardrijkskunde van nederland.
# geïllustreerde aardrijkskunde van nederland
#
#
#
# „het groot duits compfot",
# het groot duits komplot
#
#
#
# „the spy jj-'ho loved me",
# the spy who loved me
#
#
#
# puddirqvariaties",
# puddingvariaties
#
#
#
# als de tuinfluiter zwij
# als de tuinfluiter zwijgt
#
#
#
# de smokkelaars van oossterhorst.
# de smokkelaars van oosterhorst
#
#
#
# en haar verzorging" —
# poes en haar verzorging
#
#
#
# torn prins op expeditie naar donker afrika.
# tom prins op expeditie naar donker afrika
#
#
#
# „moord in met villapark",
# moord in het villapark
#
#
#
# gesellscha/tst-issenschaften und philosophie.
# gesellschaftswissenschaften und philosophie
#
#
#
# eeuwig babyion.
# eeuwig babylon
#
#
#
# praat me niet van.... de school
# praat me niet van de school
#
#
#
# de prediking werd
# wegen der prediking
#
#
#
# vijfling (met
# eerste vijfling
#
#
#
# wat «pelen we onderwe»?
# wat spelen we onderweg?
#
#
#
# ezel m'jn »ewoner.
# ezel mijn bewoner
#
#
#
# lente ln de herfst.
# lente in de herfst
#
#
#
# „de bijl in de baanderboo
# de bijl in de baanderboom
#
#
#
# „geboortestad"
# geboorte-stad
#
#
#
# instrumentarium ▼oor een winter.
# instrumentarium voor een winter
#
#
#
# rsenbloesem en kapi
# kersebloesem en kapitaal
#
#
#
# wat groeit er in de moestuin'
# wat groeit er in de moestuin?
#
#
#
# geheel. „het schaakspel in de kunsten cultuurhistorie,"
# het schaakspel in de kunst- en cultuurhistorie
#
#
#
# beumkes: „executie vaneen verleden."
# executie van een verleden
#
#
#
# „aangemuntennagemunt." een in
# aangemunt en nagemunt
#
#
#
# „ondernemerswiizer".
# ondernemerswijzer
#
#
#
# „verlegen en onzeker",
# verlegen & onzeker
#
#
#
# „angsten en fobieën",
# angsten & fobieën
#
#
#
# r. boddeke: vissen
# vissen & vissen
#
#
#
# de betorerd. bruidsnacht;
# de betoverde bruidsnacht
#
#
#
# — die
# die bewährung
#
#
#
# (inleiding tol het schaakspel;
# inleiding tot het schaakspel
#
#
#
# blggles en het luipaardmysterie
# biggles en het luipaardmysterie
#
#
#
# ali rara en zün tachtig raadsels.
# ali rara en zijn 80 raadsels
#
#
#
# - de ""%■[*
# de kleine republiek
#
#
#
# - de edel** mrs. henley.
# de edelman, en, mrs. henley
#
#
#
# - de
# de koets
#
#
#
# - de%. amerikaanse roman.
# de grote amerikaanse roman
#
#
#
# „gerontologi
# gerontologie
#
#
#
# het produktiebedrljf.
# het produktiebedrijf
#
#
#
# 'monimbo'
# monimbó
#
#
#
# vis «nl zwemmen
# vis wil zwemmen
#
#
#
# ,£lseviers aquariumvissen encyclopedie"
#  elseviers aquariumvissen encyclopedie
#
#
#
# naam socrates-methode
# socrates methode
#
#
#
# ,£lseviers aquariumvissen encyclopedie"
#  elseviers aquariumvissen encyclopedie
#
#
#
# de tuin bij het huis
# uw tuin bij het huis
#
#
#
# radio-
# radio-astronomie
#
#
#
# het paard van ome loeki.
# het paard van ome loeks
#
#
#
# de vlucht van rogtr brook.
# de vlucht van roger brook
#
#
#
# hoogovens hoogovens ij
# hoogovens ijmuiden 1918-1968
#
#
#
# — „in 't
# in 't zadel!
#
#
#
# de jong — volièrevogels in hun stamland.
# hoe leven onze volièrevogels in hun stamland
#
#
#
# dood rn bourgondië
# dood in bourgondië
#
#
#
# bouwput. de
# de bouwput
#
#
#
# het meisje van andros en alle overige toneelstukken, door
# het meisje van andros en alle overige bewaarde toneelstukken
#
#
#
# ...
#
#
#
# — de
# de fortuinzoekers
#
#
#
# ktbwtler, quaker, demokraten.
# künstler, quäker, demokraten
#
#
#
# en, wat een gedoe".
# vrijen, wat een gedoe
#
#
#
# „bommen op new rork".
# bommen op new york
#
#
#
# „wiet bij spot alleen".
# niet bij spot alleen
#
#
#
# „de grondsla-9?n der aritmetica".
# de grondslagen der aritmetica
#
#
#
# vier opstellen over j. c.
# vier opstellen over j.c. bloem
#
#
#
# — het naakte
# het naakte bestaan
#
#
#
# yemant lust met bal, of met reket te spelen. . .?
# \ heeft yemant lust met bal, of met reket te spelen?\
#
#
#
# aduertentiè'n 1830-1930.
# advertentiën 1830-1930
#
#
#
# of de spaanse erfenis. -
# furia of de spaanse erfenis
#
#
#
# psychische prootetnen bij jongeren
# psychische problemen bij jongeren
#
#
#
# k"8 v«n koningin wilhelmina
# ontmoetingen met koningin wilhelmina
#
#
#
# ..iherenivrhalen'j vol wijsheid en symboliek.
# dierenverhalen vol wijsheid en symboliek
#
#
#
# sche denkers
# russische denkers
#
#
#
# om grasparkieten op
# prisma grasparkieten boek
#
#
#
# nieuwsbrief psychologie en maatschappij.
# nieuwsbrief psychologie & maatschappij
#
#
#
# dos deutsche dilemma,
# das deutsche dilemma
#
#
#
# dat ik de weg naar het licht de
# de weg naar het licht en andere verhalen
#
#
#
# „verhalen en recepten uit het verre oosten",
# verhalen & recepten uit het verre oosten
#
#
#
# „een daa van 36 uur".
# een dag van 36 uur
#
#
#
# leven en werk van d. v.
# leven en werk van d.v. coornhert
#
#
#
# e. van vriesland. spiegel van de nederlandse poëzie
# spiegel van de nederlandse poëzie door alle eeuwen
#
#
#
# biggie» iet een val.
# biggles zet een val
#
#
#
# biggles en d. ■,.„
# biggles en de kroonjuwelen
#
#
#
# biggles en d. ■,.„
# biggles en de piratenschat
#
#
#
# biggle» in china.
# biggles in china
#
#
#
# biggles en d. ■,.„
# biggles en de goudpiraten
#
#
#
# anderson, „ik houd van de "ii monet".
# ik houd van de tuin van monet
#
#
#
# „de pr>js van de vrijheid".
# de prijs van de vrijheid
#
#
#
# kwartet
# schaduw-kwartet
#
#
#
# de friese païingaken
# de friese palingaken
#
#
#
# „raak me (niet) aan
# raak me (niet) aan!
#
#
#
# geboden". vijf op hoop van zegen.
# vijf geboden op hoop van zegen
#
#
#
# ls deze ook goed meneer?
# is deze ook goed meneer?
#
#
#
# in oude i ansichten"
# jubbega-schurega in oude ansichten
#
#
#
# das beschadigte leben.
# das beschädigte leben
#
#
#
# „koningin sophie, 1818-1877",
# koningin sophie 1818-1877
#
#
#
# aan taf>l met de kapitein.
# aan tafel met de kapitein
#
#
#
# „de arabische mentalueit",
# de arabische mentaliteit
#
#
#
# elefctronisch jaarboekje
# electronisch jaarboekje
#
#
#
# — waarom staan die kaarsjes
# waarom staan die kaarsjes daar?
#
#
#
# «et gewicht van d« buitenstaander.
# het gewicht van de buitenstaander
#
#
#
# in israël in
# alledag in israël
#
#
#
# de opkomst van rood
# de opkomst van rood-china
#
#
#
# „made in usa"
# made in u.$.a.
#
#
#
# sociaal demo, ralie in friesland
# 100 jaar sociaal-democratie in friesland
#
#
#
# 'kleuren in de middeleeuwen'
# kleuren van de middeleeuwen
#
#
#
# het :
# het verlies
#
#
#
# ..een loflied voor leibouwitz".
# een loflied voor leibowitz
#
#
#
# het ivoud der belofte.
# het woud der belofte
#
#
#
# — met mijn '<'<-'•
# met mijn teer gestel
#
#
#
# „werkboek" is
# werkboek bijenhouden
#
#
#
# gedichten e aforismen
# gedichten en aforismen
#
#
#
# boo: „dofcter korczdk, ik stik in ac klas."
# ' dokter korczak, ik stik in de klas'
#
#
#
# astma, bronchitis en allergie dokter r. voorhorst:
# dokter r. voorhorst over astma, bronchitis, allergie
#
#
#
# het proces „charles de gaulle".
# het proces \charles de gaulle\
#
#
#
# j. a. blaauw: laatste rit van een taxichauffeur.
# laatste rit van een taxichauffeur en andere moordzaken
#
#
#
# mist mamma airnee;
# miss mamma aimee
#
#
#
# als liefhebberij -
# dwergkonijnen als liefhebberij
#
#
#
# — „elseviers
# elseviers paddestoelengids
#
#
#
# „christiaan brumngs 1736-1805".
# christiaan brunings, 1736-1805
#
#
#
# het vaarreglement vn vraag en antwoord.
# het vaarreglement in vraag en antwoord
#
#
#
# julia en de bazooka staan vijftien verhalen
# julia en de bazooka en andere verhalen
#
#
#
# „het dikke schn/t
# het dikke schrift
#
#
#
# kjoe-kio* of de lijdenschap van een aanrander.
# kjoe-kjoe, of de lijdenschap van een aanrander
#
#
#
# 40ptus be-leefd aanbevolen.
# 40+ be-leefd aanbevolen
#
#
#
# - „het
# het manneneiland
#
#
#
# — nachtboot naar puerto
# nachtboot naar puerto vedra
#
#
#
# mannen zyn lekkerbekken
# mannen zijn lekkerbekken
#
#
#
# in de kerk. in de kerk
# het vergeten ambt in de kerk
#
#
#
# ja kun ie krijgen.
# ja kun je krijgen
#
#
#
# - „de gedenkwaardige reizen van bontekoe.' de
# de gedenkwaardige reizen van willem ijsbrantsz bontekoe
#
#
#
# „verhaaltjes ran rroeger".
# verhaaltjes van vroeger
#
#
#
# ■len hollander in parijs".
# een hollander in parijs
#
#
#
# + bijbelse dagkalender
# bijbelse dagkalender 1972
#
#
#
# vrouwen en hun nartners over pnd.
# vrouwen en hun partners over pnd
#
#
#
# arabieren. de
# de moeras-arabieren
#
#
#
# klosse: kaas & wijn-feest.
# kaas & wijn feest
#
#
#
# • pms soor aangepaste voeding.
# overwin pms door aangepaste voeding
#
#
#
# meester-romancier louis-paul boon.
# louis paul boon
#
#
#
# „alleen bij uiterste noodzaak".
# alleen bij uiterste noodzaak?
#
#
#
# groot grouenboek
# groot grollenboek
#
#
#
# figuraiitenjaar
# figurantenjaar
#
#
#
# g< en geschreven is twee.
# gezegd en geschreven is twee
#
#
#
# „mutanten
# mutanten-milieu
#
#
#
# ei
# ei-ei
#
#
#
# — jood in arabiè'-got in israël.
# jood in arabië, goi in israël
#
#
#
# een stijl van leven
# een werkplaats van leven
#
#
#
# - „hal,i«'k e;,,'", harteloze wereld"
# haven in een harteloze wereld
#
#
#
# ht ox-bow incident.
# het ox-bow incident
#
#
#
# architectuur & stedebouw in indonesië 1870-1970.
# architectuur & stedebouw in indonesie 1870-1970
#
#
#
# - ..worden u bent",
# worden wie je bent
#
#
#
# - „de
# de schirmer-erfenis
#
#
#
# - „de stuiter".
# de knalblauwe stuiter
#
#
#
# — thieme's hengelboek. een uit het
# thieme's hengelboek het handboek voor hengelaars
#
#
#
# ■*• bijbelse dagkalender
# bijbelse dagkalender 1971
#
#
#
# wie het eerste zn stenen kwijt is.
# wie het eerste z'n stenen kwijt is
#
#
#
# eiland tri de zon.
# eiland in de zon
#
#
#
# karakteranalyse.
# charakteranalyse
#
#
#
# achilleus - een
# achilleus megalopsuchos (man-met-de-grote-ziel)
#
#
#
# 'wat doen ire met ons geloof?'
# wat doen we met ons geloof?
#
#
#
# bruidssuikers en wittebroodsweken.
# bruidssuikers & wittebroodsweken
#
#
#
# achter de floostermuren
# achter de kloostermuren
#
#
#
# diervormen wan hout
# diervormen van hout
#
#
#
# „5c op de valreep" en 5c
# please sir! 5c op de valreep
#
#
#
# automaten kontra "malthus.
# automaten contra malthus
#
#
#
# vrou w voor mijn zoon".
# een vrouw voor mijn zoon
#
#
#
# verdedigircgsrede van sokrates.
# verdedigingsrede van sokrates
#
#
#
# — de
# de opblaasvrouwtjes
#
#
#
# worden en slank blijven
# slank worden slank blijven
#
#
#
# «rheorie der geschichtswissenscnayt
# theorie der geschichtswissenschaft
#
#
#
# wylde blom
# wylde blome
#
#
#
# voor fairoglen". het
# toekomst voor fairoglen
#
#
#
# zomers run toen en andere nostalgische verhalen.
# zomers van toen en andere nostalgische verhalen
#
#
#
# „grafrozen voor mc
# grafrozen voor mcgregor
#
#
#
# - ....... moeder naar de derde trede
# als moeder naar de derde trede gaat
#
#
#
# ,^zelf terrtiel verven"
# zelf textiel verven
#
#
#
# boezemwaterschappcn en polders in midden-friesland.
# boezemwaterschappen en polders in midden-friesland
#
#
#
# rijangsl is zó te verhelpen.
# rijangst is zó te verhelpen
#
#
#
# bij |ou of bij mij'
# bij jou of bij mij?
#
#
#
# — „de kooi van
# de kooi van licht
#
#
#
# dubbelnaam „een tijdelijk monument- links de helikopterlijn"
# een tijdelijk monument. links van de helikopterlijn
#
#
#
# koekplank
# koekplanken
#
#
#
# - ,;frivolité - vroeger
# frivolité vroeger en nu
#
#
#
# andermans veten".
# andermans veren
#
#
#
# „tien generaties poiesz",
# 10 generaties poiesz
#
#
#
# „de trotste bedelaars".
# de trotse bedelaars
#
#
#
# - . vaders".
# huizen zonder vaders
#
#
#
# — der violette
# der violette käfig
#
#
#
# „de belastingcursus 1984" is
# de belastingcursus van teleac
#
#
#
# michelangelo en de schepping van de sixtijnse kapel.
# michelangelo & de schepping van de sixtijnse kapel
#
#
#
# de olieman en andere liedjes.
# de olieman & andere liedjes
#
#
#
# - ..het transcendente meditatieprogramma voor zakenmensen".
# het transcendente meditatie programma voor zakenmensen
#
#
#
# gröszerer versuch über den schmutz;
# grösserer versuch über den schmutz
#
#
#
# eine schone bescherung
# eine schöne bescherung
#
#
#
# ii „poel van
# poel van vuur
#
#
#
# — hoe hoort het
# hoe hoort het nu?
#
#
#
# (paul vlaanderen en liet genève-mysterie)
# paul vlaanderen en het genève-mysterie
#
#
#
# (de saint op ie loop
# de saint op de loop
#
#
#
# en de saint en de
# de saint en de mensenhandelaren
#
#
#
# (detective voor dag en dnuw(,
# detective voor dag en dauw
#
#
#
# (zoem:,
# zoem!
#
#
#
# + modern ballet in nederland" - het
# hans van manen+ modern ballet in nederland
#
#
#
# - „waar ben
# waar ben je?
#
#
#
# bladen uit een daaboek.
# bladen uit een dagboek
#
#
#
# hwer host it wei?
# hwer hast it wei?
#
#
#
# hel fascisme en de nieuwe i'riihrid
# het fascisme en de nieuwe vrijheid
#
#
#
# de '■
# de fluitspeelster
#
#
#
# ...ƒ. van oudshoorn
# j. van oudshoorn
#
#
#
# jde beren ran churthill",
# de beren van churchill
#
#
#
# berusting, of de geschiedenis van een huwelijk
# berusting of de geschiedenis van een huwelijk
#
#
#
# breëkwater.
# breekwater
#
#
#
# paul bowles:,het huis van de
# het huis van de spin
#
#
#
# besturing van het mensetyk gedrag.
# besturing van het menselijk gedrag
#
#
#
# moord op rotterdam.
# gifmoord op rotterdam
#
#
#
# —de dreigend* zon.
# de dreigende zon
#
#
#
# de ruxge zeilers.
# de ruige zeilers
#
#
#
# „de cock en de moorain séance" (fontein,
# de cock en de moord in seance
#
#
#
# ..ik heb het .jen lief.
# ik heb het leven lief
#
#
#
# „galgelied".
# galgenlied
#
#
#
# - „de
# de poppenkastmoorden
#
#
#
# „de lotgevallen lüri lanoe jan silver".
# de lotgevallen van lange jan silver
#
#
#
# „oorlogsoxit
# oorlogsbuit
#
#
#
# „de man 2? atlantis"
# de man van atlantis
#
#
#
# in dienst van de 'koninklijke'
# in dienst van de \koninklijke\
#
#
#
# — 'adiós companeros'.
# ¡ adiós compañeros!
#
#
#
# — al wat menselijk
# al wat menselijk is
#
#
#
# vit de gedenkschrijven van de heer von schnabelewopski.
# uit de gedenkschriften van den heer von schnabelewopski
#
#
#
# ..lekker eten ~„ toch vermageren",
# lekker eten en toch vermageren
#
#
#
# groene ruimte-, he-t nfg
# in de groene ruimte
#
#
#
# „vogels run europa".
# vogels van europa
#
#
#
# ontmoetingen met - n karel appel.
# ontmoetingen met corneille en karel appel
#
#
#
# - fe-» spin op
# een spin op tafel
#
#
#
# nathulie
# nathalie
#
#
#
# — weerzien in
# weerzien in lipizza
#
#
#
# de literatuur van sybren polet:
# de liternatuur van sybren polet
#
#
#
# 50.'bert schierbeek en het onbgrensde
# bert schierbeek en het onbegrensde
#
#
#
# het dieet
# het neder-dieet
#
#
#
# het veld wan eer
# het veld van eer
#
#
#
# dolle kate, bendeleidster
# dolle kate bendeleidster
#
#
#
# naor het middelpunt der aarde.
# naar het middelpunt der aarde
#
#
#
# elsevier* judo-boek.
# elseviers judo-boek
#
#
#
# blld und plakat.
# bild und plakat
#
#
#
# bloempjes der vruegd, voor de lieve jeugd.
# bloempjes der vreugd' voor de lieve jeugd
#
#
#
# young: „opkomst: van de meritocratie 1870-2033,"
# de opkomst van de meritocratie 1870-2033
#
#
#
# .janny hill's kookboek"
# fanny hill's kookboek
#
#
#
# rosa stond niet 0p...
# rosa stond niet op
#
#
#
# architectuui en stedebouw 1850--1940 ui friesland
# architectuur en stedebouw in friesland, 1850-1940
#
#
#
# het geheim von greenpeace
# het geheim van greenpeace
#
#
#
# een steen in te vijver.
# een steen in de vijver
#
#
#
# theresia avila en haar tijd", met
# teresia van avila en haar tijd
#
#
#
# - „vlinder op ei
# vlinder op een paardebloem
#
#
#
# analytische sozial-psychologie und gesellschaftstheorie
# analytische sozialpsychologie und gesellschaftstheorie
#
#
#
# en sprookjes „onze beste volksverhalen" door dr. tj. w. r. de haan 224 blz.,
# onze beste volksverhalen bijeengezocht, opnieuw verteld en van toelichtingen voorzien door tj.w.r. de haan
#
#
#
# de widerbroken reis.
# de onderbroken reis
#
#
#
# desmond bagley —
# desmond bagley omnibus
#
#
#
# „prettige feestdagen".
# prettige feestdagen!
#
#
#
# simone, well, de 'rode jeanne d'arc'
# simone weil, de \rode jeanne d'arc\
#
#
#
# dokter haibertsma
# dokter halbertsma
#
#
#
# bundel prisma-puzzels,
# prisma-puzzels 27
#
#
#
# het heldenlied van aaapito robles";
# het heldenlied van agapito robles
#
#
#
# terug naar huis en andere verhale>
# terug naar huis en andere verhalen
#
#
#
# dagboek en briefen van mewes jans bakker (1764-1824).
# dagboek en brieven van mewes jans bakker (1764-1824)
#
#
#
# zojuist verschenen.... 19e internationaal eci-schaaktoernooi,europees jeugdkampioenschap 1992,5 as van gent,
# 19e internationaal eci schaaktoernooi te sas van gent 17 t
#
#
#
# „wegwijs in de paardenstal".
# wegwijs in de paardestal
#
#
#
# sdmtliche schriften;
# sämtliche schriften
#
#
#
# jvieut/j handboek soldaat".
# nieuw handboek soldaat
#
#
#
# compleet"
# juf-compleet
#
#
#
# „recepten x'oor de snelkookpan",
# recepten voor de snelkookpan
#
#
#
# * boekje open-serie - „rijst en 'inzen"
# een boekje open over rijst en linzen
#
#
#
# ■a^oorkom verstopping"
# voorkom verstopping
#
#
#
# de boekhandelaar en de chirurg.
# de boekhandelaar & de chirurg
#
#
#
# frequin: „volgende i, verhalen over geboorte, le• dood".
# \volgende patiënt!\ verhalen over geboorte, leven en dood
#
#
#
# btw tabellen —
# samsoms btw tabellen
#
#
#
# — pleidooi voor een decentralisatie van degezondheidszorg.
# pleidooi voor een decentralisatie van de gezondheidszorg
#
#
#
# internationale politiek,
# internationale politik
#
#
#
# -.grundkurs im wiesenschaftlichen definiëren;
# grundkurs im wissenschaftlichen definieren
#
#
#
# handbuch theologischer grundoegriffe,
# handbuch theologischer grundbegriffe
#
#
#
# cartoens.
# cartoons
#
#
#
# „een snoer bleedkoralen"
# een snoer bloedkoralen
#
#
#
# scheren hun zwarte schapen. uitgave:
# manteau-auteurs scheren hun zwarte schapen
#
#
#
# „abortus, pro en contra".
# abortus pro en contra
#
#
#
# de goede herder volo schapen- de
# de goede herder en zijn schapen
#
#
#
# „modcr"* seksualiteit".
# moderne seksualiteit
#
#
#
# - „als een
# als een vloedgolf
#
#
#
# li iken wel gek!"
# we lijken wel gek!
#
#
#
# „100 vragen over vitaminen en mwerulen".
# 100 vragen over vitaminen en mineralen
#
#
#
# '100 vragen over...' in
# 100 vragen over psoriasis
#
#
#
# schrijvers m nu» landschap;
# schrijvers in hun landschap
#
#
#
# „waar zijn we mee bezig,
# waar zijn we mee bezig?
#
#
#
# alles bijzonder. alles
# in alles bijzonder
#
#
#
# literair akkoord 20
# literair akkoord 18
#
#
#
# * science fiction-verhalen,
# science fiction verhalen
#
#
#
# simak; „moeder aarde,"
# moeder aarde nv
#
#
#
# „mijn broer miehael,"
# mijn broer michael
#
#
#
# nederlands woordenboek is
# spectrum nederlands woordenboek
#
#
#
# gebeden van chrl«ten_»
# gebeden van christenen
#
#
#
# ™ï* de nieuwe
# de nieuwe belastingwetten
#
#
#
# * .__?__.?£ verhalen
# klassieke russische verhalen
#
#
#
# hemeltjelief.
# hemeltjelief?
#
#
#
# chisholm & consorten; uitg.
# eustace chisholm & consorten
#
#
#
# het eiland ameland en zijn bewoners",
# het eiland ameland en zijne bewoners
#
#
#
# „lang i zond leven"
# lang en gezond leven
#
#
#
# met hart en ziel"- in
# leven met hart en ziel
#
#
#
# „guerilla",
# guerrilla
#
#
#
# „tromgeroffel in rangas",
# tromgeroffel in rancas
#
#
#
# wijmakersboekje
# wijnmakersboekje
#
#
#
# na 35 jaar onderzoek en ontginning ln de ijsselmeerpolders.
# na vijfendertig jaar onderzoek en ontginning in de ijsselmeerpolders
#
#
#
# statistisch overzicht 1960—
# statische overzicht 1960
#
#
#
# eenvoudige macramé
# eenvoudig macramé
#
#
#
# frieensforschung und gesellschaftskritik.
# friedensforschung und gesellschaftskritik
#
#
#
# prioritdten für die orschungspolitik.
# prioritäten für die forschungspolitik
#
#
#
# ohm führt die biologie?
# wohin führt die biologie?
#
#
#
# gefahrdete zukunft;
# gefährdete zukunft
#
#
#
# - gebed en
# gebed en meditatie
#
#
#
# met stad onder sterren
# stad onder de sterren
#
#
#
# „blijf w overgang de baas".
# blijf de overgang de baas
#
#
#
# eenzame engeleipn
# eenzame engelen
#
#
#
# „woningbouw voor arbeiders in het 19-de eeuwse
# woningbouw voor arbeiders in het 19de-eeuwse amsterdam
#
#
#
# - „space shuttle
# space shuttle \columbia\
#
#
#
# nieuw ideeën voor zandschüderen.
# nieuwe ideeën voor zandschilderen
#
#
#
# lets van warmte,
# iets van warmte
#
#
#
# stlna en lars in de bergen.
# stina en lars in de bergen
#
#
#
# de korte brief 0!( het lange afscheid.
# de korte brief bij het lange afscheid
#
#
#
# dichter bij later'
# dicht bij later
#
#
#
# - „de
# de godenmakers
#
#
#
# - in de ruimte
# wonen in de ruimte
#
#
#
# gele huis op de pinnasberg of de 36 eros-broeders tf an sankt pauli.
# het gele huis op de pinnasberg, of de 36 erosbroeders van sankt pauli
#
#
#
# —dé koning van het puin.
# de koning van het puin
#
#
#
# the best of h. c. artman]
# the best of h. c. artmann
#
#
#
# d<s. ha„s de m nog eenentwintig andere verhalen
# hans de ponnie en nog eenentwintig andere verhalen
